# %% [markdown]
# # Deep Learning Bootcamp: PyTorch Deep Neural Networks from Ground Up
#
# In this notebook, we will start with the foundational blocks of Neural Networks and progressively delve into more complex architectures and techniques.
#
# We will use the CIFAR-10 dataset to experiment with building, optimizing, and tuning Deep Learning models to tackle image classification tasks.
#
# ## Setting Up the Environment
# Let's set up our environment by importing the necessary libraries and checking for GPU availability. If a GPU is not available, the training process will default to the CPU.
#
# > conda create --name jads_bootcamp python=3.11
# >
# > conda activate jads_bootcamp
# >
# > pip install -r requirements.txt
#
# Follow the instruction in [Installing PyTorch](https://pytorch.org/get-started/locally/) to install Pytorch in the most appropriate way for your PC configuration.
#
# Navigate to the directory containing the .ipynb file and run jupyter notebook:
# > jupyter notebook

# %%
# Imports and GPU check
# %matplotlib inline
import os
import random
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.init as init
import torchvision
import torchvision.transforms as transforms
from torch import nn, optim
from torch.utils.data import DataLoader, Subset
from torchvision import models
from tqdm import tqdm
from itertools import product

# Fix HTTPS certificate error
import ssl
ssl_create_default_https_context = ssl._create_unverified_context

# Check for GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ### Reproducibility
# Achieving reproducible results is a cornerstone of scientific research.
#
# In the context of Deep Learning, this means ensuring that a model will produce the same results on the same data, regardless of when or where it is run. This is challenging due to the inherent randomness in model initialization and data shuffling.
# To avoid (or minimize) it, we fix the random seed across all libraries that generate random numbers.

# %%
def set_seed(seed=42):
    """Sets the seed for reproducibility."""
    # Python RNG
    random.seed(seed)
    
    # PyTorch RNGs
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    
    # Numpy RNG
    np.random.seed(seed)
    
    # OS RNG
    os.environ['PYTHONHASHSEED'] = str(seed)

def worker_init_fn(worker_id):    
    """Ensure that the data loading process is deterministic."""
    np.random.seed(np.random.get_state()[1][0] + worker_id)
    
set_seed(42)

# %% [markdown]
# ## Hyperparameters
# Hyperparameters are the configuration settings used to structure the learning process.
#
# In our case, we include settings on the learning rate, the batch size, the number of training epochs, and the size of the dataset for training. Adjusting these parameters can significantly affect the model's performance and the learning efficiency

# %%
# Hyperparameters
batch_size = 128
dataset_size = 5000  # Reduced dataset size for quicker training

epochs = 50
learning_rate = 0.001

# %% [markdown]
# ## Dataset
# We use the CIFAR-10 dataset, consisting of 60,000 32x32 color images in 10 classes, with 6,000 images per class.
#
# The dataset is divided into 50,000 training images and 10,000 test images.
#
# To speed up the training process, we reduce the number of training images to 10,000.

# %%
transform = transforms.Compose([
    transforms.ToTensor() # Convert images to tensors
])

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
full_train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

# Reducing the dataset size 
indices = list(range(dataset_size))
train_dataset = Subset(full_train_dataset, indices)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=worker_init_fn)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, worker_init_fn=worker_init_fn)

print(f"Full train set size: {len(full_train_dataset)} - Reduced train set size: {len(train_dataset)} - Test set size: {len(test_dataset)}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Full train set size: 50000 - Reduced train set size: 5000 - Test set size: 10000

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
#
# ```python
# transform = transforms.Compose([
#     transforms.ToTensor() # Convert images to tensors
# ])
# ```
#
# **Transforms:** Data transformations are crucial in Deep Learning for preprocessing and augmenting your data. Here, `transforms.Compose` allows us to chain together different transformations. `transforms.ToTensor()` converts images into PyTorch tensors, automatically scaling the image data to the range [0, 1].
#
# ```python
# test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# full_train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# ```
#
# **Loading CIFAR10:** These lines load the CIFAR10 dataset for training and testing. The `train` parameter specifies whether to load the training subset (True) or the test subset (False). `download=True` will download the data to the `root` directory if it's not already present. The `transform` argument applies the specified transformations to the dataset.
#
# ```python
# indices = list(range(dataset_size))
# train_dataset = Subset(full_train_dataset, indices)
# ```
#
# **Dataset Reduction:** To speed up training for educational purposes, we might want to work with a smaller subset of the data. This is achieved by creating a list of `indices` that define the subset and then using `Subset` to extract those specific samples from the full dataset.
#
# ```python
# train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=worker_init_fn)
# test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, worker_init_fn=worker_init_fn)
# ```
#
# **Data Loaders:** The `DataLoader` wraps a dataset and provides an iterable over the dataset. The `batch_size` defines how many samples per batch to load. `shuffle=True` shuffles the data every epoch, ensuring the model doesn't learn anything from the order of the samples. The `worker_init_fn` can be used for reproducibility of the data loading process, especially when using random transformations.
# </span>

# %% [markdown]
# ### Normalize the inputs
#
# Let's normalize the input data, to improve the learning process, by using Standard Normalization.
# we first need to calculate the mean and variance of the pixel values across the entire training dataset. These statistics are then used to normalize both the training and validation/test datasets.

# %%
def calculate_mean_and_variance(loader):
    mean = 0.0
    variance = 0.0
    total_images = 0

    for images, _ in loader:
        # Rearrange batch to be the shape of [B, C, W * H]
        images = images.view(images.size(0), images.size(1), -1)
        # Update total_images
        total_images += images.size(0)
        # Compute mean and variance here
        mean += images.mean(2).sum(0) 
        variance += images.var(2).sum(0)

    # Final mean and variance
    mean /= total_images
    variance /= total_images

    return mean, variance

# Assuming train_loader is defined and loaded
mean, variance = calculate_mean_and_variance(train_loader)
std = variance.sqrt()

print(f"Mean: {mean}")
print(f"Standard Deviation: {std}")
# Out:
# Mean: tensor([0.4913, 0.4814, 0.4445])
# Standard Deviation: tensor([0.2124, 0.2098, 0.2133])

# %% [markdown]
# Let's add the input normalization

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)  # Normalize images
])

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
full_train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

# Reducing the dataset size 
indices = list(range(dataset_size))
train_dataset = Subset(full_train_dataset, indices)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=worker_init_fn)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, worker_init_fn=worker_init_fn)

print(f"Full train set size: {len(full_train_dataset)} - Reduced train set size: {len(train_dataset)} - Test set size: {len(test_dataset)}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Full train set size: 50000 - Reduced train set size: 5000 - Test set size: 10000

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code breakdown
#
# ```python
# transform = transforms.Compose([
#     transforms.ToTensor(),
#     transforms.Normalize(mean=mean, std=std)  # Normalize images
# ])
# ```
#
# **Normalization:** After converting the images into tensors, `transforms.Normalize(mean=mean, std=std)` standardizes the pixel values across the dataset. This normalization process adjusts the pixel values so that they have a smean of 0 and a standard deviation of 1.
#
# </span>

# %% [markdown]
# ## Input Visualization
# Let's take a look to some of our input images

# %%
num_images = 5

def denormalize(img, mean, std):
    """Denormalizes an image to its original form using mean and std"""
    mean = torch.tensor(mean).reshape(-1, 1, 1) if not isinstance(mean, torch.Tensor) else mean.reshape(-1, 1, 1)
    std = torch.tensor(std).reshape(-1, 1, 1) if not isinstance(std, torch.Tensor) else std.reshape(-1, 1, 1)
    denorm_img = img * std + mean  # Apply denormalization
    return denorm_img
    
def imshow(img, mean, std):
    """Shows an image by first denormalizing it"""
    img = denormalize(img, mean, std)  # Denormalize
    img = torch.clamp(img, 0, 255)  # Ensure the image is within [0, 255]
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Select random images and plot them with labels
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# Display the images with denormalization
for i in range(num_images):
    image, label = test_dataset[i][0], test_dataset[i][1]  # Ensure that you're accessing the tensor image
    print('Label:', classes[label])
    imshow(image, mean, std)  # Pass mean and std as tensors
# Out:
# Label: cat
# Label: ship
# Label: ship
# Label: plane
# Label: frog

# %% [markdown]
# ## Basic Neural Network Architecture
#
# Let's start our exploration with a basic Linear Model to establish a performance baseline.
#
# This model, consisting of a single linear layer, is quick to train but typically underperforms on complex tasks due to its inability to capture non-linear relations in the training data.
#
# In PyTorch, the layers come with a default weight initialization. Let's use them in this first training iteration.

# %%
# Linear Model
class Linear_Model(nn.Module):
    def __init__(self):
        super(Linear_Model, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_stack = nn.Sequential(
            nn.Linear(3*32*32, 10),            
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_stack(x)
        return logits

linear_model = Linear_Model().to(device)
print(linear_model)
# Out:
# Linear_Model(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_stack): Sequential(
#     (0): Linear(in_features=3072, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code breakdown
#
# Let's examine the structure of a basic linear model:
#
# 1. **Base Class Inheritance (`nn.Module`):** In PyTorch, all neural network modules should inherit from `nn.Module`. This base class helps in organizing the network, and it provides essential functionalities for training and inference.
#
# 2. **Initialization Method (`__init__`):** This method initializes the layers of our linear model. Our model consists of two main parts:
#    - `nn.Flatten()`: This layer flattens the input tensors. For an image dataset like CIFAR10, which consists of 3x32x32 images (3 channels, 32x32 pixels), flattening transforms each image into a 1D tensor of 3*32*32 = 3072 elements. Flattening is a common preprocessing step before feeding data into a linear layer.
#    - `nn.Linear(3*32*32, 10)`: The linear layer, or fully connected layer, maps the flattened input to the output. Here, it maps from 3072 input features to 10 output features, corresponding to the 10 classes of the CIFAR10 dataset. This layer will learn the weights and biases during training.
#
# 3. **Forward Method (`forward`):** This method defines how the input `x` flows through the model. First, we flatten the input, and then we pass it through the linear layer. The output `logits` represents the raw predictions that our model makes, which can then be passed through a softmax function for classification tasks.
#
# 4. **Model Instantiation and Device Allocation:** `linear_model = Linear_Model().to(device)` creates an instance of our linear model and moves it to a device (CPU or GPU), allowing for accelerated computation. The `print(linear_model)` statement displays the architecture of our model, helping us verify its structure.
#
# </span>

# %% [markdown]
# How many parameters do the model have?

# %%
# Calculate and print the number of parameters per layer
total_param_num = 0
for name, param in linear_model.named_parameters():
    print(f"Layer: {name}, Parameters: {param.numel()}")
    total_param_num += param.numel()

print(f"\nTotal number of parameters: {total_param_num}")
# Out:
# Layer: linear_stack.0.weight, Parameters: 30720
# Layer: linear_stack.0.bias, Parameters: 10
#
# Total number of parameters: 30730

# %% [markdown]
# ## Loss function and optimizer
#
# When choosing a loss function and an optimizer for a neural network, it's important to consider the specific task at hand.
#
# For classification tasks, Cross Entropy Loss and optimizers like SGD or Adam are common choices.

# %%
model = linear_model

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
#
# **Loss Function (Criterion):**
# - `criterion = nn.CrossEntropyLoss()`: The loss function measures how well the model performs on the given dataset. For classification tasks, **CrossEntropyLoss** is commonly used. It combines **softmax** (a function that converts logits to probabilities) with **log loss** (negative log likelihood), effectively dealing with multi-class classification problems. This function expects raw output from the model (logits) and calculates the difference between the predicted probabilities and the actual class labels.
#
# **Optimizer:**
# - `optimizer = optim.SGD(model.parameters(), lr=learning_rate)`: The optimizer updates the model's parameters (weights and biases) using the gradients computed during backpropagation. Here, we use **Stochastic Gradient Descent (SGD)** as our optimizer. `model.parameters()` tells the optimizer which parameters to adjust, and `lr=learning_rate` sets the step size for each iteration during optimization. The learning rate is a critical hyperparameter that controls how much we are adjusting the weights of our network concerning the loss gradient. Too small a learning rate may result in slow convergence, while too large a learning rate can cause the model to oscillate or even diverge.
#
# </span>

# %% [markdown]
# ## Model Training
#
# The training loop is where the model learns from the data. In each epoch, the model makes predictions, calculates the error (loss), and uses backpropagation to adjust the weights.
#
# ### Training Process Overview
#
# During training, for each batch of data, the following steps occur:
# 1. **Forward Pass:** The model computes predictions based on the input data.
# 2. **Compute Loss:** The difference between the predictions and the actual labels is calculated using the loss function.
# 3. **Backward Pass:** The model backpropagates the loss to compute the gradients of the loss with respect to each parameter.
# 4. **Update Parameters:** The optimizer uses the gradients calculated during the backward pass to update the model's parameters.

# %%
# Training and Validation Loop
for epoch in tqdm(range(epochs)):
    # Training Phase
    model.train()  # Set the model to training mode
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to the appropriate device
        
        optimizer.zero_grad()  # Zero the gradients to prevent accumulation
        outputs = model(images)  # Forward pass
        loss = criterion(outputs, labels)  # Calculate the loss
        loss.backward()  # Backward pass
        optimizer.step()  # Optimize the model
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:55<00:00,  1.12s/it]

# %% [markdown]
# ### Model Training with Validation Loop
#
# Using the previous training loop is not a smart choice because it lacks the following critical components for training a neural network effectively:
#
# 1. **Logging and Monitoring**: Logging training metrics such as losses, and accuracy, is crucial for tracking the model's performance over time. Without proper logging and monitoring, it becomes challenging to diagnose issues, compare different models, or make informed decisions about model improvements.
#
# 1. **Validation Step**: the previous training loop misses a validation step after each epoch. Validating the model on a separate validation dataset is essential to monitor its generalization performance and detect overfitting. Without validation, it's difficult to determine if the model is learning to generalize well beyond the training data.
#
# Let's address these issues.

# %%
# Lists to store metrics
train_losses = []
train_accuracies = []
validation_losses = []
validation_accuracies = []

# Training and Validation Loop
start_time = time.time()
for epoch in range(epochs):
    # Training Phase
    model.train()  # Set the model to training mode
    train_loss = 0
    correct_train = 0
    total_train = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to the appropriate device
        
        optimizer.zero_grad()  # Zero the gradients to prevent accumulation
        outputs = model(images)  # Forward pass
        loss = criterion(outputs, labels)  # Calculate the loss
        loss.backward()  # Backward pass
        optimizer.step()  # Optimize the model
        
        train_loss += loss.item() * images.size(0)  # Accumulate the loss
        _, predicted = torch.max(outputs, 1)  # Get predictions
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()  # Calculate correct predictions
  
    train_loss /= len(train_loader.dataset)
    train_accuracy = 100 * correct_train / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    
    # Validation Phase
    model.eval()  # Set the model to evaluation mode
    validation_loss = 0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():  # Disable gradient calculation
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)  # Move data to the appropriate device
            outputs = model(images)  # Forward pass
            loss = criterion(outputs, labels)  # Calculate the loss
            
            validation_loss += loss.item() * images.size(0)  # Accumulate the loss
            _, predicted = torch.max(outputs, 1)  # Get predictions
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()  # Calculate correct predictions
    
    validation_loss /= len(test_loader.dataset)
    validation_accuracy = 100 * correct_val / total_val
    validation_losses.append(validation_loss)
    validation_accuracies.append(validation_accuracy)

    # Print metrics
    print(f'Epoch [{epoch+1}/{epochs}], Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.2f}%')

end_time = time.time()
execution_time = end_time - start_time

minutes = int(execution_time // 60)  
seconds = int(execution_time % 60)   
print(f"\nExecution time: {minutes:02}:{seconds:02}")
# Out:
# Epoch [1/50], Training Loss: 1.5945, Training Accuracy: 46.64%, Validation Loss: 1.8458, Validation Accuracy: 36.21%
# Epoch [2/50], Training Loss: 1.5929, Training Accuracy: 46.68%, Validation Loss: 1.8414, Validation Accuracy: 36.73%
# Epoch [3/50], Training Loss: 1.5890, Training Accuracy: 47.00%, Validation Loss: 1.8402, Validation Accuracy: 36.64%
# Epoch [4/50], Training Loss: 1.5863, Training Accuracy: 47.64%, Validation Loss: 1.8420, Validation Accuracy: 36.32%
# Epoch [5/50], Training Loss: 1.5836, Training Accuracy: 47.40%, Validation Loss: 1.8472, Validation Accuracy: 36.11%
# Epoch [6/50], Training Loss: 1.5830, Training Accuracy: 47.18%, Validation Loss: 1.8405, Validation Accuracy: 36.53%
# Epoch [7/50], Training Loss: 1.5790, Training Accuracy: 47.50%, Validation Loss: 1.8400, Validation Accuracy: 36.63%
# Epoch [8/50], Training Loss: 1.5757, Training Accuracy: 47.42%, Validation Loss: 1.8407, Validation Accuracy: 36.49%
# Epoch [9/50], Training Loss: 1.5735, Training Accuracy: 47.48%, Validation Loss: 1.8434, Validation Accuracy: 36.41%
# Epoch [10/50], Training Loss: 1.5718, Training Accuracy: 47.36%, Validation Loss: 1.8444, Validation Accuracy: 36.48%
# Epoch [11/50], Training Loss: 1.5695, Training Accuracy: 47.50%, Validation Loss: 1.8411, Validation Accuracy: 36.24%
# Epoch [12/50], Training Loss: 1.5669, Training Accuracy: 47.66%, Validation Loss: 1.8453, Validation Accuracy: 36.37%
# Epoch [13/50], Training Loss: 1.5650, Training Accuracy: 47.52%, Validation Loss: 1.8434, Validation Accuracy: 36.56%
# Epoch [14/50], Training Loss: 1.5620, Training Accuracy: 47.80%, Validation Loss: 1.8434, Validation Accuracy: 36.17%
# Epoch [15/50], Training Loss: 1.5598, Training Accuracy: 47.76%, Validation Loss: 1.8407, Validation Accuracy: 36.54%
# Epoch [16/50], Training Loss: 1.5577, Training Accuracy: 48.20%, Validation Loss: 1.8457, Validation Accuracy: 36.45%
# Epoch [17/50], Training Loss: 1.5558, Training Accuracy: 47.38%, Validation Loss: 1.8462, Validation Accuracy: 36.60%
# Epoch [18/50], Training Loss: 1.5542, Training Accuracy: 47.96%, Validation Loss: 1.8442, Validation Accuracy: 36.69%
# Epoch [19/50], Training Loss: 1.5493, Training Accuracy: 48.12%, Validation Loss: 1.8392, Validation Accuracy: 36.66%
# Epoch [20/50], Training Loss: 1.5491, Training Accuracy: 48.16%, Validation Loss: 1.8439, Validation Accuracy: 35.97%
# Epoch [21/50], Training Loss: 1.5466, Training Accuracy: 48.44%, Validation Loss: 1.8534, Validation Accuracy: 35.91%
# Epoch [22/50], Training Loss: 1.5460, Training Accuracy: 48.32%, Validation Loss: 1.8411, Validation Accuracy: 36.51%
# Epoch [23/50], Training Loss: 1.5432, Training Accuracy: 48.38%, Validation Loss: 1.8460, Validation Accuracy: 36.26%
# Epoch [24/50], Training Loss: 1.5420, Training Accuracy: 48.60%, Validation Loss: 1.8415, Validation Accuracy: 36.36%
# Epoch [25/50], Training Loss: 1.5396, Training Accuracy: 48.62%, Validation Loss: 1.8435, Validation Accuracy: 36.63%
# Epoch [26/50], Training Loss: 1.5361, Training Accuracy: 48.66%, Validation Loss: 1.8469, Validation Accuracy: 36.36%
# Epoch [27/50], Training Loss: 1.5342, Training Accuracy: 49.08%, Validation Loss: 1.8431, Validation Accuracy: 36.52%
# Epoch [28/50], Training Loss: 1.5325, Training Accuracy: 48.74%, Validation Loss: 1.8461, Validation Accuracy: 36.39%
# Epoch [29/50], Training Loss: 1.5310, Training Accuracy: 48.98%, Validation Loss: 1.8518, Validation Accuracy: 36.08%
# Epoch [30/50], Training Loss: 1.5304, Training Accuracy: 49.02%, Validation Loss: 1.8451, Validation Accuracy: 36.52%
# Epoch [31/50], Training Loss: 1.5274, Training Accuracy: 48.70%, Validation Loss: 1.8449, Validation Accuracy: 36.38%
# Epoch [32/50], Training Loss: 1.5254, Training Accuracy: 48.88%, Validation Loss: 1.8405, Validation Accuracy: 36.87%
# Epoch [33/50], Training Loss: 1.5229, Training Accuracy: 49.32%, Validation Loss: 1.8411, Validation Accuracy: 36.80%
# Epoch [34/50], Training Loss: 1.5209, Training Accuracy: 48.82%, Validation Loss: 1.8481, Validation Accuracy: 36.14%
# Epoch [35/50], Training Loss: 1.5198, Training Accuracy: 49.04%, Validation Loss: 1.8494, Validation Accuracy: 36.34%
# Epoch [36/50], Training Loss: 1.5185, Training Accuracy: 49.36%, Validation Loss: 1.8466, Validation Accuracy: 36.42%
# Epoch [37/50], Training Loss: 1.5165, Training Accuracy: 49.02%, Validation Loss: 1.8530, Validation Accuracy: 36.24%
# Epoch [38/50], Training Loss: 1.5151, Training Accuracy: 49.36%, Validation Loss: 1.8445, Validation Accuracy: 36.22%
# Epoch [39/50], Training Loss: 1.5122, Training Accuracy: 49.62%, Validation Loss: 1.8512, Validation Accuracy: 36.08%
# Epoch [40/50], Training Loss: 1.5112, Training Accuracy: 49.44%, Validation Loss: 1.8502, Validation Accuracy: 36.39%
# Epoch [41/50], Training Loss: 1.5101, Training Accuracy: 49.58%, Validation Loss: 1.8441, Validation Accuracy: 36.48%
# Epoch [42/50], Training Loss: 1.5072, Training Accuracy: 49.46%, Validation Loss: 1.8502, Validation Accuracy: 36.55%
# Epoch [43/50], Training Loss: 1.5077, Training Accuracy: 49.80%, Validation Loss: 1.8502, Validation Accuracy: 36.03%
# Epoch [44/50], Training Loss: 1.5048, Training Accuracy: 49.84%, Validation Loss: 1.8495, Validation Accuracy: 36.67%
# Epoch [45/50], Training Loss: 1.5027, Training Accuracy: 50.02%, Validation Loss: 1.8512, Validation Accuracy: 35.86%
# Epoch [46/50], Training Loss: 1.5005, Training Accuracy: 49.98%, Validation Loss: 1.8457, Validation Accuracy: 36.55%
# Epoch [47/50], Training Loss: 1.4984, Training Accuracy: 49.88%, Validation Loss: 1.8488, Validation Accuracy: 36.34%
# Epoch [48/50], Training Loss: 1.4970, Training Accuracy: 50.18%, Validation Loss: 1.8474, Validation Accuracy: 36.52%
# Epoch [49/50], Training Loss: 1.4958, Training Accuracy: 49.90%, Validation Loss: 1.8633, Validation Accuracy: 35.51%
# Epoch [50/50], Training Loss: 1.4948, Training Accuracy: 50.18%, Validation Loss: 1.8576, Validation Accuracy: 36.01%
#
# Execution time: 02:23

# %% [markdown]
# ## Metrics and Plotting
#
# Let's plot training set and validation set loss, and accuracy.

# %%
# Plotting Training vs. Validation Loss and Accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.title('Training vs. Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Let's refactor your code into two distinct functions, one for the training and validation loop and another for plotting the metrics, to re-utilize them more easily.

# %%
def train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device):
    train_losses = []
    train_accuracies = []
    validation_losses = []
    validation_accuracies = []
    
    start_time = time.time()
    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_loss, correct_train, total_train = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_loss /= len(train_loader.dataset)
        train_accuracy = 100 * correct_train / total_train
        
        # Validation Phase
        model.eval()
        validation_loss, correct_val, total_val = 0, 0, 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                validation_loss += loss.item() * images.size(0)
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()
        
        validation_loss /= len(test_loader.dataset)
        validation_accuracy = 100 * correct_val / total_val
        
        # Store metrics
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)
        validation_losses.append(validation_loss)
        validation_accuracies.append(validation_accuracy)
        
        print(f'Epoch [{epoch+1}/{epochs}], Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.2f}%')
    
    end_time = time.time()
    execution_time = end_time - start_time
    minutes = int(execution_time // 60)
    seconds = int(execution_time % 60)
    print(f"\nExecution time: {minutes:02}:{seconds:02}")
    
    return train_losses, train_accuracies, validation_losses, validation_accuracies

def plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies):
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(validation_losses, label='Validation Loss')
    plt.title('Training vs. Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(validation_accuracies, label='Validation Accuracy')
    plt.title('Training vs. Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Underfitting
# Due to its simplicity, the linear model has limited expressive power and lacks the capacity to learn the distinctions between different classes. effectively.
#
# Let's define a DNN model by introducing hidden layers with non-linear activation functions (ReLU in this case) to increase the model's capacity to learn complex patterns
#
# While PyTorch automatically applies proper layer initialization by default, let's explicitly set the weight initialization in this specific case.

# %%
# DNN Model
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(3072, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10)
        )

        # Initialize weights using He initialization explicitly
        for layer in self.modules():
            # Applies He initialization to each linear layer
            if isinstance(layer, nn.Linear):
                init.kaiming_normal_(layer.weight, mode='fan_out', nonlinearity='relu')
                
                # Initialize biases to zero
                if layer.bias is not None:
                    init.constant_(layer.bias, 0)

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

dnn_model = DNN().to(device)
print(dnn_model)
# Out:
# DNN(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=3072, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=256, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
#
# We now turn our attention to a more complex model than the linear one we previously discussed.
#
# ```python
#         self.linear_relu_stack = nn.Sequential(
#             nn.Linear(3072, 1024),
#             nn.ReLU(),
#             nn.Linear(1024, 512),
#             nn.ReLU(),
#             ...
#             nn.Linear(64, 10)
#         )
# ```
#
# - **Dense Layers with Activation:** The `self.linear_relu_stack` is a sequence of linear layers (`nn.Linear`) interspersed with ReLU activation functions (`nn.ReLU`). This stack transforms the flattened input from 3072 dimensions down to 10 dimensions, corresponding to our class labels.
#
# ##### Weight Initialization
#
# ```python
# for layer in self.modules():
#     if isinstance(layer, nn.Linear):
#         init.kaiming_normal_(layer.weight, mode='fan_out', nonlinearity='relu')
#         if layer.bias is not None:
#             init.constant_(layer.bias, 0)
# ```
#
# - **He Initialization:** This loop iterates through all modules in our model. When it finds a linear layer, it applies He (also known as Kaiming) initialization to the layer's weights. This initialization strategy is designed for layers followed by ReLU activations and helps in maintaining the variance of activations across layers, promoting efficient learning. Biases are set to zero as a starting point, ensuring a neutral starting bias for each neuron.
#
# </span>

# %% [markdown]
# How many parameters do the model have?

# %%
# Calculate and print the number of parameters per layer
total_param_num = 0
for name, param in dnn_model.named_parameters():
    print(f"Layer: {name}, Parameters: {param.numel()}")
    total_param_num += param.numel()

print(f"\nTotal number of parameters: {total_param_num}")
# Out:
# Layer: linear_relu_stack.0.weight, Parameters: 3145728
# Layer: linear_relu_stack.0.bias, Parameters: 1024
# Layer: linear_relu_stack.2.weight, Parameters: 524288
# Layer: linear_relu_stack.2.bias, Parameters: 512
# Layer: linear_relu_stack.4.weight, Parameters: 131072
# Layer: linear_relu_stack.4.bias, Parameters: 256
# Layer: linear_relu_stack.6.weight, Parameters: 32768
# Layer: linear_relu_stack.6.bias, Parameters: 128
# Layer: linear_relu_stack.8.weight, Parameters: 8192
# Layer: linear_relu_stack.8.bias, Parameters: 64
# Layer: linear_relu_stack.10.weight, Parameters: 640
# Layer: linear_relu_stack.10.bias, Parameters: 10
#
# Total number of parameters: 3844682

# %% [markdown]
# Let's use the same training pipeline we used earlier

# %%
model = dnn_model
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device)
plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies)
# Out:
# Epoch [1/50], Training Loss: 11.8862, Training Accuracy: 16.56%, Validation Loss: 7.3715, Validation Accuracy: 17.66%
# Epoch [2/50], Training Loss: 4.5790, Training Accuracy: 23.58%, Validation Loss: 4.6142, Validation Accuracy: 19.35%
# Epoch [3/50], Training Loss: 3.1258, Training Accuracy: 28.56%, Validation Loss: 4.0519, Validation Accuracy: 19.93%
# Epoch [4/50], Training Loss: 2.5094, Training Accuracy: 33.28%, Validation Loss: 3.9044, Validation Accuracy: 20.51%
# Epoch [5/50], Training Loss: 2.1553, Training Accuracy: 37.74%, Validation Loss: 3.5179, Validation Accuracy: 22.06%
# Epoch [6/50], Training Loss: 1.8758, Training Accuracy: 42.68%, Validation Loss: 3.5169, Validation Accuracy: 22.70%
# Epoch [7/50], Training Loss: 1.6948, Training Accuracy: 46.74%, Validation Loss: 3.4739, Validation Accuracy: 22.66%
# Epoch [8/50], Training Loss: 1.5314, Training Accuracy: 51.02%, Validation Loss: 3.3925, Validation Accuracy: 22.81%
# Epoch [9/50], Training Loss: 1.4073, Training Accuracy: 55.02%, Validation Loss: 3.5314, Validation Accuracy: 23.31%
# Epoch [10/50], Training Loss: 1.3124, Training Accuracy: 57.56%, Validation Loss: 3.4101, Validation Accuracy: 23.14%
# Epoch [11/50], Training Loss: 1.2203, Training Accuracy: 60.22%, Validation Loss: 3.4921, Validation Accuracy: 23.37%
# Epoch [12/50], Training Loss: 1.1453, Training Accuracy: 63.00%, Validation Loss: 3.4000, Validation Accuracy: 23.47%
# Epoch [13/50], Training Loss: 1.0814, Training Accuracy: 65.36%, Validation Loss: 3.3832, Validation Accuracy: 24.22%
# Epoch [14/50], Training Loss: 1.0231, Training Accuracy: 67.54%, Validation Loss: 3.4792, Validation Accuracy: 23.50%
# Epoch [15/50], Training Loss: 0.9665, Training Accuracy: 70.48%, Validation Loss: 3.4333, Validation Accuracy: 24.16%
# Epoch [16/50], Training Loss: 0.9169, Training Accuracy: 71.64%, Validation Loss: 3.4306, Validation Accuracy: 23.93%
# Epoch [17/50], Training Loss: 0.8735, Training Accuracy: 73.78%, Validation Loss: 3.4849, Validation Accuracy: 23.91%
# Epoch [18/50], Training Loss: 0.8316, Training Accuracy: 75.28%, Validation Loss: 3.4389, Validation Accuracy: 24.15%
# Epoch [19/50], Training Loss: 0.7947, Training Accuracy: 77.24%, Validation Loss: 3.4584, Validation Accuracy: 24.19%
# Epoch [20/50], Training Loss: 0.7607, Training Accuracy: 78.18%, Validation Loss: 3.4861, Validation Accuracy: 24.62%
# Epoch [21/50], Training Loss: 0.7312, Training Accuracy: 79.12%, Validation Loss: 3.5170, Validation Accuracy: 24.07%
# Epoch [22/50], Training Loss: 0.7044, Training Accuracy: 80.46%, Validation Loss: 3.4951, Validation Accuracy: 24.55%
# Epoch [23/50], Training Loss: 0.6730, Training Accuracy: 81.52%, Validation Loss: 3.5441, Validation Accuracy: 24.50%
# Epoch [24/50], Training Loss: 0.6507, Training Accuracy: 82.30%, Validation Loss: 3.4958, Validation Accuracy: 24.53%
# Epoch [25/50], Training Loss: 0.6261, Training Accuracy: 83.40%, Validation Loss: 3.5330, Validation Accuracy: 24.66%
# Epoch [26/50], Training Loss: 0.6052, Training Accuracy: 84.24%, Validation Loss: 3.5297, Validation Accuracy: 24.74%
# Epoch [27/50], Training Loss: 0.5889, Training Accuracy: 84.52%, Validation Loss: 3.5223, Validation Accuracy: 24.68%
# Epoch [28/50], Training Loss: 0.5651, Training Accuracy: 85.78%, Validation Loss: 3.5893, Validation Accuracy: 24.82%
# Epoch [29/50], Training Loss: 0.5495, Training Accuracy: 86.26%, Validation Loss: 3.5845, Validation Accuracy: 24.62%
# Epoch [30/50], Training Loss: 0.5306, Training Accuracy: 86.90%, Validation Loss: 3.5853, Validation Accuracy: 25.24%
# Epoch [31/50], Training Loss: 0.5133, Training Accuracy: 87.70%, Validation Loss: 3.6215, Validation Accuracy: 24.88%
# Epoch [32/50], Training Loss: 0.5026, Training Accuracy: 88.18%, Validation Loss: 3.5893, Validation Accuracy: 24.96%
# Epoch [33/50], Training Loss: 0.4836, Training Accuracy: 88.72%, Validation Loss: 3.5962, Validation Accuracy: 25.03%
# Epoch [34/50], Training Loss: 0.4708, Training Accuracy: 89.02%, Validation Loss: 3.6006, Validation Accuracy: 24.94%
# Epoch [35/50], Training Loss: 0.4576, Training Accuracy: 89.44%, Validation Loss: 3.6515, Validation Accuracy: 25.38%
# Epoch [36/50], Training Loss: 0.4437, Training Accuracy: 89.64%, Validation Loss: 3.6831, Validation Accuracy: 24.78%
# Epoch [37/50], Training Loss: 0.4370, Training Accuracy: 90.02%, Validation Loss: 3.6666, Validation Accuracy: 25.22%
# Epoch [38/50], Training Loss: 0.4294, Training Accuracy: 90.36%, Validation Loss: 3.6931, Validation Accuracy: 25.03%
# Epoch [39/50], Training Loss: 0.4132, Training Accuracy: 90.94%, Validation Loss: 3.6861, Validation Accuracy: 24.61%
# Epoch [40/50], Training Loss: 0.4125, Training Accuracy: 91.00%, Validation Loss: 3.6474, Validation Accuracy: 25.51%
# Epoch [41/50], Training Loss: 0.3936, Training Accuracy: 91.56%, Validation Loss: 3.6752, Validation Accuracy: 25.64%
# Epoch [42/50], Training Loss: 0.3794, Training Accuracy: 91.96%, Validation Loss: 3.7301, Validation Accuracy: 25.45%
# Epoch [43/50], Training Loss: 0.3717, Training Accuracy: 92.36%, Validation Loss: 3.6997, Validation Accuracy: 25.51%
# Epoch [44/50], Training Loss: 0.3620, Training Accuracy: 92.58%, Validation Loss: 3.7238, Validation Accuracy: 25.62%
# Epoch [45/50], Training Loss: 0.3519, Training Accuracy: 92.94%, Validation Loss: 3.7298, Validation Accuracy: 25.31%
# Epoch [46/50], Training Loss: 0.3467, Training Accuracy: 93.06%, Validation Loss: 3.7243, Validation Accuracy: 25.63%
# Epoch [47/50], Training Loss: 0.3354, Training Accuracy: 93.42%, Validation Loss: 3.7650, Validation Accuracy: 25.36%
# Epoch [48/50], Training Loss: 0.3294, Training Accuracy: 93.70%, Validation Loss: 3.7725, Validation Accuracy: 25.58%
# Epoch [49/50], Training Loss: 0.3217, Training Accuracy: 93.70%, Validation Loss: 3.7658, Validation Accuracy: 25.12%
# Epoch [50/50], Training Loss: 0.3158, Training Accuracy: 93.90%, Validation Loss: 3.7753, Validation Accuracy: 25.67%
#
# Execution time: 03:12

# %% [markdown]
# ## Improve the Optimizer choice
#
# Can we converge faster?
# Let's change the optimizer and use Adam optimizer!
#
# An alternative to SGD, the Adam optimizer, combines the benefits of two extensions of Stochastic Gradient Descent: Adaptive Gradient Algorithm (AdaGrad) and Root Mean Square Propagation (RMSProp). Adam computes adaptive learning rates for each parameter.
#
# In practice, Adam is often recommended as the default optimizer for many types of neural networks because it requires minimal tuning.
#
# For many tasks, Adam converges faster than SGD due to its adaptive learning rate properties.

# %%
model = DNN().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device)
plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies)
# Out:
# Epoch [1/50], Training Loss: 13.4155, Training Accuracy: 19.44%, Validation Loss: 5.7094, Validation Accuracy: 24.06%
# Epoch [2/50], Training Loss: 4.0456, Training Accuracy: 28.02%, Validation Loss: 4.3829, Validation Accuracy: 25.28%
# Epoch [3/50], Training Loss: 2.6601, Training Accuracy: 35.60%, Validation Loss: 3.0440, Validation Accuracy: 28.49%
# Epoch [4/50], Training Loss: 1.9759, Training Accuracy: 43.22%, Validation Loss: 2.7020, Validation Accuracy: 27.45%
# Epoch [5/50], Training Loss: 1.5852, Training Accuracy: 50.40%, Validation Loss: 2.4492, Validation Accuracy: 33.75%
# Epoch [6/50], Training Loss: 1.2633, Training Accuracy: 58.76%, Validation Loss: 2.5863, Validation Accuracy: 31.63%
# Epoch [7/50], Training Loss: 1.0939, Training Accuracy: 64.32%, Validation Loss: 2.6484, Validation Accuracy: 32.24%
# Epoch [8/50], Training Loss: 1.1961, Training Accuracy: 64.32%, Validation Loss: 2.5700, Validation Accuracy: 34.20%
# Epoch [9/50], Training Loss: 1.0879, Training Accuracy: 65.74%, Validation Loss: 2.7583, Validation Accuracy: 33.17%
# Epoch [10/50], Training Loss: 0.9280, Training Accuracy: 70.76%, Validation Loss: 2.7237, Validation Accuracy: 32.88%
# Epoch [11/50], Training Loss: 0.8457, Training Accuracy: 74.28%, Validation Loss: 2.7507, Validation Accuracy: 34.47%
# Epoch [12/50], Training Loss: 0.6968, Training Accuracy: 77.98%, Validation Loss: 2.8651, Validation Accuracy: 34.85%
# Epoch [13/50], Training Loss: 0.7834, Training Accuracy: 74.98%, Validation Loss: 2.8799, Validation Accuracy: 34.74%
# Epoch [14/50], Training Loss: 0.6120, Training Accuracy: 80.70%, Validation Loss: 2.9034, Validation Accuracy: 35.19%
# Epoch [15/50], Training Loss: 0.4292, Training Accuracy: 86.74%, Validation Loss: 3.0932, Validation Accuracy: 35.39%
# Epoch [16/50], Training Loss: 0.6102, Training Accuracy: 82.18%, Validation Loss: 3.0512, Validation Accuracy: 35.46%
# Epoch [17/50], Training Loss: 0.4092, Training Accuracy: 87.08%, Validation Loss: 3.0035, Validation Accuracy: 37.47%
# Epoch [18/50], Training Loss: 0.7165, Training Accuracy: 78.72%, Validation Loss: 3.7618, Validation Accuracy: 34.61%
# Epoch [19/50], Training Loss: 1.1824, Training Accuracy: 68.32%, Validation Loss: 3.6835, Validation Accuracy: 32.10%
# Epoch [20/50], Training Loss: 1.2736, Training Accuracy: 64.16%, Validation Loss: 3.4070, Validation Accuracy: 31.48%
# Epoch [21/50], Training Loss: 1.1733, Training Accuracy: 65.60%, Validation Loss: 2.9582, Validation Accuracy: 34.48%
# Epoch [22/50], Training Loss: 0.7949, Training Accuracy: 74.56%, Validation Loss: 3.0414, Validation Accuracy: 35.90%
# Epoch [23/50], Training Loss: 0.5970, Training Accuracy: 81.22%, Validation Loss: 3.0697, Validation Accuracy: 36.76%
# Epoch [24/50], Training Loss: 0.3618, Training Accuracy: 88.92%, Validation Loss: 3.2383, Validation Accuracy: 36.25%
# Epoch [25/50], Training Loss: 0.2665, Training Accuracy: 92.48%, Validation Loss: 3.2677, Validation Accuracy: 37.70%
# Epoch [26/50], Training Loss: 0.2345, Training Accuracy: 93.32%, Validation Loss: 3.3053, Validation Accuracy: 38.51%
# Epoch [27/50], Training Loss: 0.1451, Training Accuracy: 96.20%, Validation Loss: 3.3965, Validation Accuracy: 38.55%
# Epoch [28/50], Training Loss: 0.1629, Training Accuracy: 95.54%, Validation Loss: 3.4816, Validation Accuracy: 38.76%
# Epoch [29/50], Training Loss: 0.1741, Training Accuracy: 95.20%, Validation Loss: 3.5097, Validation Accuracy: 38.98%
# Epoch [30/50], Training Loss: 0.1243, Training Accuracy: 96.80%, Validation Loss: 3.6127, Validation Accuracy: 39.19%
# Epoch [31/50], Training Loss: 0.0878, Training Accuracy: 97.68%, Validation Loss: 3.7287, Validation Accuracy: 39.38%
# Epoch [32/50], Training Loss: 0.0756, Training Accuracy: 98.16%, Validation Loss: 3.7895, Validation Accuracy: 39.50%
# Epoch [33/50], Training Loss: 0.1066, Training Accuracy: 97.40%, Validation Loss: 3.8701, Validation Accuracy: 38.08%
# Epoch [34/50], Training Loss: 0.3071, Training Accuracy: 92.06%, Validation Loss: 4.2886, Validation Accuracy: 36.84%
# Epoch [35/50], Training Loss: 0.3840, Training Accuracy: 88.52%, Validation Loss: 3.8304, Validation Accuracy: 37.35%
# Epoch [36/50], Training Loss: 0.2953, Training Accuracy: 90.96%, Validation Loss: 3.9826, Validation Accuracy: 36.25%
# Epoch [37/50], Training Loss: 0.2590, Training Accuracy: 91.48%, Validation Loss: 4.1463, Validation Accuracy: 36.11%
# Epoch [38/50], Training Loss: 0.7179, Training Accuracy: 80.98%, Validation Loss: 4.2016, Validation Accuracy: 36.54%
# Epoch [39/50], Training Loss: 0.6176, Training Accuracy: 82.50%, Validation Loss: 4.0524, Validation Accuracy: 36.09%
# Epoch [40/50], Training Loss: 0.8741, Training Accuracy: 75.90%, Validation Loss: 3.9801, Validation Accuracy: 35.78%
# Epoch [41/50], Training Loss: 0.9963, Training Accuracy: 73.92%, Validation Loss: 4.0541, Validation Accuracy: 35.39%
# Epoch [42/50], Training Loss: 0.5745, Training Accuracy: 82.52%, Validation Loss: 3.7476, Validation Accuracy: 37.71%
# Epoch [43/50], Training Loss: 0.2919, Training Accuracy: 90.98%, Validation Loss: 3.8420, Validation Accuracy: 38.59%
# Epoch [44/50], Training Loss: 0.2036, Training Accuracy: 93.66%, Validation Loss: 3.9896, Validation Accuracy: 38.51%
# Epoch [45/50], Training Loss: 0.1626, Training Accuracy: 95.62%, Validation Loss: 4.0758, Validation Accuracy: 38.68%
# Epoch [46/50], Training Loss: 0.0739, Training Accuracy: 98.06%, Validation Loss: 4.1598, Validation Accuracy: 39.11%
# Epoch [47/50], Training Loss: 0.0610, Training Accuracy: 98.24%, Validation Loss: 4.1881, Validation Accuracy: 39.47%
# Epoch [48/50], Training Loss: 0.0426, Training Accuracy: 98.92%, Validation Loss: 4.1976, Validation Accuracy: 39.59%
# Epoch [49/50], Training Loss: 0.0162, Training Accuracy: 99.70%, Validation Loss: 4.2785, Validation Accuracy: 40.30%
# Epoch [50/50], Training Loss: 0.0153, Training Accuracy: 99.78%, Validation Loss: 4.3100, Validation Accuracy: 40.20%
#
# Execution time: 02:56

# %% [markdown]
# ## Regularization
# We are overfitting! Let's try to regularize our model.
# We will try to implement both L2 Regularization and Dropout.
#
# - **L2 regularization** is added through the optimizer, by setting the `weight_decay` parameter, which applies to all the parameters of the model.
# - **Dropout** is included within the model definition, by adding nn.Dropout layers in the sequential model where appropriate.
#
# ### L2 Regularization
# L2 regularization, also known as weight decay, adds a penalty on the size of the weights, encouraging them to be small.
#
# When you define your optimizer, you can specify the `weight_decay` parameter to enable L2 regularization. The value of weight_decay determines the strength of the regularization. A common choice is to start experimenting with values like 1e-5 to 1e-4:
#
# ```python
# optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
# ```

# %%
model = DNN().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4) # Added L2 regularization

train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device)
plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies)
# Out:
# Epoch [1/50], Training Loss: 12.6914, Training Accuracy: 17.26%, Validation Loss: 6.4605, Validation Accuracy: 19.17%
# Epoch [2/50], Training Loss: 3.5935, Training Accuracy: 25.06%, Validation Loss: 2.7489, Validation Accuracy: 20.81%
# Epoch [3/50], Training Loss: 2.0894, Training Accuracy: 31.24%, Validation Loss: 2.3424, Validation Accuracy: 24.23%
# Epoch [4/50], Training Loss: 1.7087, Training Accuracy: 40.08%, Validation Loss: 2.3958, Validation Accuracy: 27.95%
# Epoch [5/50], Training Loss: 1.6380, Training Accuracy: 43.70%, Validation Loss: 2.4831, Validation Accuracy: 28.17%
# Epoch [6/50], Training Loss: 1.4954, Training Accuracy: 48.58%, Validation Loss: 2.5244, Validation Accuracy: 29.68%
# Epoch [7/50], Training Loss: 1.3852, Training Accuracy: 52.40%, Validation Loss: 2.4072, Validation Accuracy: 30.90%
# Epoch [8/50], Training Loss: 1.3960, Training Accuracy: 52.94%, Validation Loss: 2.6299, Validation Accuracy: 26.87%
# Epoch [9/50], Training Loss: 1.3378, Training Accuracy: 55.44%, Validation Loss: 2.5952, Validation Accuracy: 30.92%
# Epoch [10/50], Training Loss: 1.3057, Training Accuracy: 55.86%, Validation Loss: 2.5962, Validation Accuracy: 31.01%
# Epoch [11/50], Training Loss: 1.0938, Training Accuracy: 61.74%, Validation Loss: 2.5379, Validation Accuracy: 33.21%
# Epoch [12/50], Training Loss: 0.9184, Training Accuracy: 68.54%, Validation Loss: 2.5493, Validation Accuracy: 34.57%
# Epoch [13/50], Training Loss: 0.7825, Training Accuracy: 73.36%, Validation Loss: 2.8378, Validation Accuracy: 32.93%
# Epoch [14/50], Training Loss: 1.0313, Training Accuracy: 64.46%, Validation Loss: 2.7703, Validation Accuracy: 33.70%
# Epoch [15/50], Training Loss: 1.0603, Training Accuracy: 65.42%, Validation Loss: 2.7111, Validation Accuracy: 34.77%
# Epoch [16/50], Training Loss: 0.9824, Training Accuracy: 67.34%, Validation Loss: 2.8713, Validation Accuracy: 33.66%
# Epoch [17/50], Training Loss: 0.8814, Training Accuracy: 70.40%, Validation Loss: 2.9407, Validation Accuracy: 32.94%
# Epoch [18/50], Training Loss: 0.7194, Training Accuracy: 75.34%, Validation Loss: 2.8542, Validation Accuracy: 35.57%
# Epoch [19/50], Training Loss: 0.5844, Training Accuracy: 80.02%, Validation Loss: 2.9159, Validation Accuracy: 34.77%
# Epoch [20/50], Training Loss: 0.5124, Training Accuracy: 82.80%, Validation Loss: 2.9086, Validation Accuracy: 36.04%
# Epoch [21/50], Training Loss: 0.4587, Training Accuracy: 84.30%, Validation Loss: 3.1955, Validation Accuracy: 35.03%
# Epoch [22/50], Training Loss: 0.4400, Training Accuracy: 85.04%, Validation Loss: 3.1991, Validation Accuracy: 36.57%
# Epoch [23/50], Training Loss: 0.3790, Training Accuracy: 87.90%, Validation Loss: 3.4096, Validation Accuracy: 36.47%
# Epoch [24/50], Training Loss: 0.8661, Training Accuracy: 72.60%, Validation Loss: 3.3165, Validation Accuracy: 32.93%
# Epoch [25/50], Training Loss: 0.8120, Training Accuracy: 73.02%, Validation Loss: 3.5424, Validation Accuracy: 36.59%
# Epoch [26/50], Training Loss: 0.5943, Training Accuracy: 80.92%, Validation Loss: 3.5909, Validation Accuracy: 34.95%
# Epoch [27/50], Training Loss: 0.5048, Training Accuracy: 83.30%, Validation Loss: 3.2131, Validation Accuracy: 37.38%
# Epoch [28/50], Training Loss: 0.5814, Training Accuracy: 81.34%, Validation Loss: 3.3419, Validation Accuracy: 36.32%
# Epoch [29/50], Training Loss: 0.4856, Training Accuracy: 84.12%, Validation Loss: 3.5168, Validation Accuracy: 36.67%
# Epoch [30/50], Training Loss: 0.3580, Training Accuracy: 88.46%, Validation Loss: 3.5386, Validation Accuracy: 37.77%
# Epoch [31/50], Training Loss: 0.2972, Training Accuracy: 90.28%, Validation Loss: 3.6540, Validation Accuracy: 37.45%
# Epoch [32/50], Training Loss: 0.2566, Training Accuracy: 91.76%, Validation Loss: 3.7688, Validation Accuracy: 38.38%
# Epoch [33/50], Training Loss: 0.2361, Training Accuracy: 92.36%, Validation Loss: 4.0881, Validation Accuracy: 37.36%
# Epoch [34/50], Training Loss: 0.2402, Training Accuracy: 92.18%, Validation Loss: 4.0419, Validation Accuracy: 37.37%
# Epoch [35/50], Training Loss: 0.3084, Training Accuracy: 89.82%, Validation Loss: 4.2194, Validation Accuracy: 36.70%
# Epoch [36/50], Training Loss: 0.5871, Training Accuracy: 81.96%, Validation Loss: 4.2536, Validation Accuracy: 34.12%
# Epoch [37/50], Training Loss: 1.2297, Training Accuracy: 64.08%, Validation Loss: 3.7136, Validation Accuracy: 31.04%
# Epoch [38/50], Training Loss: 1.5576, Training Accuracy: 52.56%, Validation Loss: 2.9680, Validation Accuracy: 30.39%
# Epoch [39/50], Training Loss: 1.7687, Training Accuracy: 40.72%, Validation Loss: 2.4493, Validation Accuracy: 28.67%
# Epoch [40/50], Training Loss: 1.4746, Training Accuracy: 48.96%, Validation Loss: 2.7467, Validation Accuracy: 31.73%
# Epoch [41/50], Training Loss: 1.0241, Training Accuracy: 64.54%, Validation Loss: 3.0782, Validation Accuracy: 34.33%
# Epoch [42/50], Training Loss: 0.7826, Training Accuracy: 72.68%, Validation Loss: 3.1273, Validation Accuracy: 36.59%
# Epoch [43/50], Training Loss: 0.5831, Training Accuracy: 79.58%, Validation Loss: 3.3682, Validation Accuracy: 37.54%
# Epoch [44/50], Training Loss: 0.5479, Training Accuracy: 81.54%, Validation Loss: 3.3438, Validation Accuracy: 36.97%
# Epoch [45/50], Training Loss: 0.3695, Training Accuracy: 87.14%, Validation Loss: 3.7787, Validation Accuracy: 37.89%
# Epoch [46/50], Training Loss: 0.3298, Training Accuracy: 89.02%, Validation Loss: 3.6659, Validation Accuracy: 38.36%
# Epoch [47/50], Training Loss: 0.2950, Training Accuracy: 89.86%, Validation Loss: 4.0763, Validation Accuracy: 38.11%
# Epoch [48/50], Training Loss: 0.2367, Training Accuracy: 92.00%, Validation Loss: 4.0801, Validation Accuracy: 38.95%
# Epoch [49/50], Training Loss: 0.2954, Training Accuracy: 90.34%, Validation Loss: 3.8324, Validation Accuracy: 37.84%
# Epoch [50/50], Training Loss: 0.2735, Training Accuracy: 91.00%, Validation Loss: 3.9576, Validation Accuracy: 38.46%
#
# Execution time: 03:06

# %% [markdown]
# ### Dropout Regularization
# Dropout is a technique used to prevent overfitting by randomly setting a fraction of input units to 0 at each update during training time, which helps to prevent neurons from co-adapting too much.
#
# Dropout is included within the model definition, by adding `nn.Dropout layers`.

# %%
# DNN Model
class DNN_Dropout(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(DNN_Dropout, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(3072, 1024),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

dnn_dropout_model = DNN_Dropout().to(device)
print(dnn_dropout_model)
# Out:
# DNN_Dropout(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=3072, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=256, out_features=128, bias=True)
#     (10): ReLU()
#     (11): Dropout(p=0.5, inplace=False)
#     (12): Linear(in_features=128, out_features=64, bias=True)
#     (13): ReLU()
#     (14): Dropout(p=0.5, inplace=False)
#     (15): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
#
# Let's examine the `DNN_Dropout` class, a variant of our previous DNN model that incorporates dropout layers.
#
# ```python
#     def __init__(self, dropout_rate=0.5):
#
#         [...]
#
#         self.linear_relu_stack = nn.Sequential(
#             nn.Linear(3072, 1024),
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             ...
#             nn.Linear(64, 10)
#         )
# ```
#
# - **Dropout Introduction:** The primary difference in this model, compared to the previous DNN module, is the addition of `nn.Dropout(dropout_rate)` layers. Dropout is a regularization technique that temporarily drops units (along with their connections) from the network during training, which helps prevent the network from becoming too dependent on any single neuron. This randomness encourages the network to learn more robust features that generalize better to unseen data.
#
# - **Dropout Rate:** The `dropout_rate` parameter specifies the probability of an element to be zeroed. A common choice is `0.5`, meaning there's a 50% chance each neuron's output will be ignored during each forward pass in training. This rate can be adjusted to balance between underfitting and overfitting.
#
# </span>

# %%
model = DNN_Dropout().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate) # NO L2 regularization

train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device)
plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies)
# Out:
# Epoch [1/50], Training Loss: 2.2893, Training Accuracy: 12.86%, Validation Loss: 2.1757, Validation Accuracy: 18.63%
# Epoch [2/50], Training Loss: 2.1837, Training Accuracy: 18.58%, Validation Loss: 2.0771, Validation Accuracy: 23.66%
# Epoch [3/50], Training Loss: 2.1161, Training Accuracy: 20.74%, Validation Loss: 2.0289, Validation Accuracy: 24.77%
# Epoch [4/50], Training Loss: 2.0682, Training Accuracy: 22.32%, Validation Loss: 1.9703, Validation Accuracy: 25.89%
# Epoch [5/50], Training Loss: 2.0422, Training Accuracy: 22.90%, Validation Loss: 1.9393, Validation Accuracy: 28.52%
# Epoch [6/50], Training Loss: 2.0071, Training Accuracy: 25.10%, Validation Loss: 1.9586, Validation Accuracy: 27.43%
# Epoch [7/50], Training Loss: 1.9684, Training Accuracy: 24.70%, Validation Loss: 1.8837, Validation Accuracy: 29.76%
# Epoch [8/50], Training Loss: 1.9433, Training Accuracy: 26.96%, Validation Loss: 1.8884, Validation Accuracy: 28.71%
# Epoch [9/50], Training Loss: 1.9334, Training Accuracy: 26.98%, Validation Loss: 1.8688, Validation Accuracy: 28.27%
# Epoch [10/50], Training Loss: 1.8970, Training Accuracy: 28.36%, Validation Loss: 1.8617, Validation Accuracy: 30.35%
# Epoch [11/50], Training Loss: 1.8901, Training Accuracy: 27.72%, Validation Loss: 1.8701, Validation Accuracy: 30.55%
# Epoch [12/50], Training Loss: 1.8570, Training Accuracy: 28.42%, Validation Loss: 1.8459, Validation Accuracy: 30.49%
# Epoch [13/50], Training Loss: 1.8259, Training Accuracy: 29.18%, Validation Loss: 1.8429, Validation Accuracy: 28.37%
# Epoch [14/50], Training Loss: 1.8412, Training Accuracy: 30.00%, Validation Loss: 1.8481, Validation Accuracy: 30.45%
# Epoch [15/50], Training Loss: 1.8280, Training Accuracy: 30.04%, Validation Loss: 1.8289, Validation Accuracy: 31.16%
# Epoch [16/50], Training Loss: 1.8100, Training Accuracy: 31.50%, Validation Loss: 1.8469, Validation Accuracy: 33.08%
# Epoch [17/50], Training Loss: 1.7896, Training Accuracy: 31.04%, Validation Loss: 1.8285, Validation Accuracy: 32.71%
# Epoch [18/50], Training Loss: 1.7702, Training Accuracy: 33.08%, Validation Loss: 1.8430, Validation Accuracy: 33.00%
# Epoch [19/50], Training Loss: 1.7813, Training Accuracy: 33.08%, Validation Loss: 1.8150, Validation Accuracy: 33.53%
# Epoch [20/50], Training Loss: 1.7380, Training Accuracy: 33.74%, Validation Loss: 1.8214, Validation Accuracy: 34.01%
# Epoch [21/50], Training Loss: 1.7406, Training Accuracy: 33.34%, Validation Loss: 1.8033, Validation Accuracy: 34.28%
# Epoch [22/50], Training Loss: 1.7226, Training Accuracy: 35.06%, Validation Loss: 1.7970, Validation Accuracy: 35.80%
# Epoch [23/50], Training Loss: 1.7117, Training Accuracy: 35.42%, Validation Loss: 1.7980, Validation Accuracy: 34.22%
# Epoch [24/50], Training Loss: 1.6655, Training Accuracy: 37.54%, Validation Loss: 1.8109, Validation Accuracy: 35.28%
# Epoch [25/50], Training Loss: 1.6855, Training Accuracy: 36.74%, Validation Loss: 1.7947, Validation Accuracy: 34.84%
# Epoch [26/50], Training Loss: 1.6612, Training Accuracy: 36.86%, Validation Loss: 1.7905, Validation Accuracy: 36.08%
# Epoch [27/50], Training Loss: 1.6382, Training Accuracy: 37.44%, Validation Loss: 1.8100, Validation Accuracy: 36.00%
# Epoch [28/50], Training Loss: 1.6546, Training Accuracy: 36.36%, Validation Loss: 1.8094, Validation Accuracy: 35.85%
# Epoch [29/50], Training Loss: 1.6469, Training Accuracy: 37.24%, Validation Loss: 1.7900, Validation Accuracy: 36.11%
# Epoch [30/50], Training Loss: 1.6418, Training Accuracy: 37.42%, Validation Loss: 1.7957, Validation Accuracy: 36.39%
# Epoch [31/50], Training Loss: 1.6321, Training Accuracy: 38.58%, Validation Loss: 1.7945, Validation Accuracy: 37.94%
# Epoch [32/50], Training Loss: 1.6203, Training Accuracy: 39.30%, Validation Loss: 1.7820, Validation Accuracy: 37.02%
# Epoch [33/50], Training Loss: 1.5797, Training Accuracy: 39.42%, Validation Loss: 1.7869, Validation Accuracy: 37.88%
# Epoch [34/50], Training Loss: 1.6241, Training Accuracy: 39.22%, Validation Loss: 1.7858, Validation Accuracy: 36.84%
# Epoch [35/50], Training Loss: 1.5993, Training Accuracy: 40.30%, Validation Loss: 1.7955, Validation Accuracy: 38.10%
# Epoch [36/50], Training Loss: 1.5900, Training Accuracy: 40.62%, Validation Loss: 1.7794, Validation Accuracy: 37.78%
# Epoch [37/50], Training Loss: 1.5349, Training Accuracy: 41.48%, Validation Loss: 1.8003, Validation Accuracy: 37.97%
# Epoch [38/50], Training Loss: 1.5457, Training Accuracy: 42.04%, Validation Loss: 1.7713, Validation Accuracy: 38.31%
# Epoch [39/50], Training Loss: 1.5347, Training Accuracy: 42.78%, Validation Loss: 1.7837, Validation Accuracy: 37.67%
# Epoch [40/50], Training Loss: 1.5338, Training Accuracy: 43.52%, Validation Loss: 1.7790, Validation Accuracy: 39.12%
# Epoch [41/50], Training Loss: 1.5127, Training Accuracy: 42.70%, Validation Loss: 1.8112, Validation Accuracy: 38.99%
# Epoch [42/50], Training Loss: 1.5029, Training Accuracy: 43.56%, Validation Loss: 1.8044, Validation Accuracy: 39.13%
# Epoch [43/50], Training Loss: 1.5407, Training Accuracy: 42.88%, Validation Loss: 1.7955, Validation Accuracy: 38.84%
# Epoch [44/50], Training Loss: 1.5053, Training Accuracy: 44.00%, Validation Loss: 1.8125, Validation Accuracy: 38.38%
# Epoch [45/50], Training Loss: 1.4875, Training Accuracy: 44.38%, Validation Loss: 1.7735, Validation Accuracy: 38.92%
# Epoch [46/50], Training Loss: 1.4767, Training Accuracy: 44.02%, Validation Loss: 1.7786, Validation Accuracy: 40.03%
# Epoch [47/50], Training Loss: 1.4411, Training Accuracy: 45.62%, Validation Loss: 1.7996, Validation Accuracy: 38.46%
# Epoch [48/50], Training Loss: 1.4402, Training Accuracy: 45.76%, Validation Loss: 1.7894, Validation Accuracy: 39.81%
# Epoch [49/50], Training Loss: 1.4876, Training Accuracy: 44.82%, Validation Loss: 1.7964, Validation Accuracy: 38.04%
# Epoch [50/50], Training Loss: 1.4689, Training Accuracy: 43.50%, Validation Loss: 1.7892, Validation Accuracy: 39.19%
#
# Execution time: 02:59

# %% [markdown]
# ..and now??
#
# We have solved the over-fitting problem, but now we are under-fitting again! What to do?
#
# Can we improve the model?

# %%
# DNN Model with Batch Normalization
class DNN_BatchNorm(nn.Module):
    def __init__(self, dropout_rate=0.2):
        super(DNN_BatchNorm, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_stack = nn.Sequential(
            nn.Linear(3072, 1024),
            nn.BatchNorm1d(1024),  # Batch Normalization
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),   # Batch Normalization
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),   # Batch Normalization
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),   # Batch Normalization
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),    # Batch Normalization
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_stack(x)
        return logits

dnn_batchnorm_model = DNN_BatchNorm().to(device)
print(dnn_batchnorm_model)
# Out:
# DNN_BatchNorm(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_stack): Sequential(
#     (0): Linear(in_features=3072, out_features=1024, bias=True)
#     (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Linear(in_features=512, out_features=256, bias=True)
#     (9): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=256, out_features=128, bias=True)
#     (13): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): Dropout(p=0.2, inplace=False)
#     (16): Linear(in_features=128, out_features=64, bias=True)
#     (17): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): Dropout(p=0.2, inplace=False)
#     (20): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
#
# ```python
#         self.linear_stack = nn.Sequential(
#             nn.Linear(3072, 1024),
#             nn.BatchNorm1d(1024),  # Batch Normalization
#             nn.ReLU(),
#             nn.Dropout(dropout_rate),
#             ...
#             nn.Linear(64, 10)
#         )
# ```
#
# - **Batch Normalization Layers:** After each linear layer (except the final one), a `nn.BatchNorm1d` layer is added. Batch Normalization normalizes the output of the previous layer by subtracting the batch mean and dividing by the batch standard deviation. This process stabilizes the learning process, accelerates the training speed, and often leads to better overall performance by reducing internal covariate shift.
#
# </span>

# %%
model = DNN_BatchNorm().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate) # NO L2 regularization

train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device)
plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies)
# Out:
# Epoch [1/50], Training Loss: 2.1103, Training Accuracy: 24.40%, Validation Loss: 1.9455, Validation Accuracy: 32.12%
# Epoch [2/50], Training Loss: 1.8813, Training Accuracy: 32.62%, Validation Loss: 1.8267, Validation Accuracy: 34.12%
# Epoch [3/50], Training Loss: 1.7670, Training Accuracy: 35.74%, Validation Loss: 1.7712, Validation Accuracy: 36.93%
# Epoch [4/50], Training Loss: 1.6865, Training Accuracy: 40.30%, Validation Loss: 1.7368, Validation Accuracy: 37.73%
# Epoch [5/50], Training Loss: 1.6029, Training Accuracy: 43.26%, Validation Loss: 1.7005, Validation Accuracy: 38.99%
# Epoch [6/50], Training Loss: 1.5588, Training Accuracy: 44.36%, Validation Loss: 1.6655, Validation Accuracy: 40.87%
# Epoch [7/50], Training Loss: 1.5123, Training Accuracy: 46.56%, Validation Loss: 1.6860, Validation Accuracy: 40.92%
# Epoch [8/50], Training Loss: 1.4882, Training Accuracy: 47.54%, Validation Loss: 1.6702, Validation Accuracy: 41.18%
# Epoch [9/50], Training Loss: 1.3940, Training Accuracy: 50.92%, Validation Loss: 1.7119, Validation Accuracy: 39.96%
# Epoch [10/50], Training Loss: 1.3280, Training Accuracy: 54.04%, Validation Loss: 1.6642, Validation Accuracy: 42.33%
# Epoch [11/50], Training Loss: 1.2848, Training Accuracy: 55.74%, Validation Loss: 1.7035, Validation Accuracy: 41.50%
# Epoch [12/50], Training Loss: 1.2430, Training Accuracy: 56.52%, Validation Loss: 1.7811, Validation Accuracy: 39.43%
# Epoch [13/50], Training Loss: 1.1892, Training Accuracy: 58.28%, Validation Loss: 1.6956, Validation Accuracy: 41.77%
# Epoch [14/50], Training Loss: 1.1629, Training Accuracy: 59.44%, Validation Loss: 1.7595, Validation Accuracy: 42.29%
# Epoch [15/50], Training Loss: 1.1521, Training Accuracy: 59.82%, Validation Loss: 1.7722, Validation Accuracy: 41.54%
# Epoch [16/50], Training Loss: 1.1288, Training Accuracy: 61.16%, Validation Loss: 1.7636, Validation Accuracy: 42.22%
# Epoch [17/50], Training Loss: 1.0599, Training Accuracy: 63.06%, Validation Loss: 1.7238, Validation Accuracy: 42.74%
# Epoch [18/50], Training Loss: 0.9855, Training Accuracy: 66.30%, Validation Loss: 1.7796, Validation Accuracy: 42.20%
# Epoch [19/50], Training Loss: 0.9766, Training Accuracy: 65.90%, Validation Loss: 1.8119, Validation Accuracy: 42.97%
# Epoch [20/50], Training Loss: 1.0199, Training Accuracy: 65.22%, Validation Loss: 1.8234, Validation Accuracy: 41.65%
# Epoch [21/50], Training Loss: 0.9294, Training Accuracy: 68.32%, Validation Loss: 1.8060, Validation Accuracy: 43.31%
# Epoch [22/50], Training Loss: 0.8971, Training Accuracy: 69.28%, Validation Loss: 1.8564, Validation Accuracy: 42.22%
# Epoch [23/50], Training Loss: 0.9598, Training Accuracy: 67.14%, Validation Loss: 1.8215, Validation Accuracy: 43.37%
# Epoch [24/50], Training Loss: 0.7957, Training Accuracy: 73.10%, Validation Loss: 1.8629, Validation Accuracy: 43.25%
# Epoch [25/50], Training Loss: 0.9360, Training Accuracy: 68.12%, Validation Loss: 1.8209, Validation Accuracy: 43.33%
# Epoch [26/50], Training Loss: 0.8445, Training Accuracy: 71.18%, Validation Loss: 1.8568, Validation Accuracy: 43.81%
# Epoch [27/50], Training Loss: 0.7434, Training Accuracy: 74.32%, Validation Loss: 1.9513, Validation Accuracy: 42.80%
# Epoch [28/50], Training Loss: 0.8384, Training Accuracy: 72.56%, Validation Loss: 1.9500, Validation Accuracy: 43.77%
# Epoch [29/50], Training Loss: 0.7959, Training Accuracy: 72.76%, Validation Loss: 1.9330, Validation Accuracy: 43.08%
# Epoch [30/50], Training Loss: 0.7789, Training Accuracy: 73.48%, Validation Loss: 1.8723, Validation Accuracy: 43.90%
# Epoch [31/50], Training Loss: 0.7126, Training Accuracy: 76.14%, Validation Loss: 1.9252, Validation Accuracy: 44.13%
# Epoch [32/50], Training Loss: 0.7285, Training Accuracy: 75.18%, Validation Loss: 1.9438, Validation Accuracy: 42.47%
# Epoch [33/50], Training Loss: 0.6584, Training Accuracy: 77.84%, Validation Loss: 1.9595, Validation Accuracy: 43.45%
# Epoch [34/50], Training Loss: 0.7086, Training Accuracy: 76.18%, Validation Loss: 2.0426, Validation Accuracy: 42.52%
# Epoch [35/50], Training Loss: 0.6543, Training Accuracy: 77.76%, Validation Loss: 1.9815, Validation Accuracy: 44.46%
# Epoch [36/50], Training Loss: 0.7107, Training Accuracy: 76.58%, Validation Loss: 1.9803, Validation Accuracy: 43.66%
# Epoch [37/50], Training Loss: 0.6481, Training Accuracy: 78.32%, Validation Loss: 2.0066, Validation Accuracy: 43.82%
# Epoch [38/50], Training Loss: 0.5831, Training Accuracy: 80.48%, Validation Loss: 2.0380, Validation Accuracy: 44.01%
# Epoch [39/50], Training Loss: 0.5422, Training Accuracy: 82.44%, Validation Loss: 2.0432, Validation Accuracy: 43.74%
# Epoch [40/50], Training Loss: 0.4650, Training Accuracy: 84.56%, Validation Loss: 2.0802, Validation Accuracy: 44.67%
# Epoch [41/50], Training Loss: 0.5405, Training Accuracy: 82.46%, Validation Loss: 2.1337, Validation Accuracy: 43.15%
# Epoch [42/50], Training Loss: 0.6929, Training Accuracy: 77.60%, Validation Loss: 2.1350, Validation Accuracy: 43.10%
# Epoch [43/50], Training Loss: 0.6413, Training Accuracy: 78.74%, Validation Loss: 2.0579, Validation Accuracy: 44.11%
# Epoch [44/50], Training Loss: 0.5511, Training Accuracy: 81.24%, Validation Loss: 2.0671, Validation Accuracy: 44.89%
# Epoch [45/50], Training Loss: 0.6730, Training Accuracy: 78.16%, Validation Loss: 2.0621, Validation Accuracy: 43.32%
# Epoch [46/50], Training Loss: 0.5203, Training Accuracy: 82.90%, Validation Loss: 2.0539, Validation Accuracy: 43.37%
# Epoch [47/50], Training Loss: 0.5074, Training Accuracy: 83.58%, Validation Loss: 2.0958, Validation Accuracy: 43.74%
# Epoch [48/50], Training Loss: 0.4423, Training Accuracy: 85.36%, Validation Loss: 2.1761, Validation Accuracy: 42.61%
# Epoch [49/50], Training Loss: 0.4354, Training Accuracy: 86.16%, Validation Loss: 2.2713, Validation Accuracy: 43.60%
# Epoch [50/50], Training Loss: 0.5173, Training Accuracy: 82.94%, Validation Loss: 2.1680, Validation Accuracy: 43.68%
#
# Execution time: 02:58

# %% [markdown]
# ## Hyperparameter search
# When embarking on a Deep Learning project, one of the most critical steps after designing your model is hyperparameter tuning.
#
# Hyperparameters significantly influence model performance, and their optimal combination can vary widely between datasets and problem types.

# %%
def train_validate_model(params, device):
    print(params)
    print()
    
    # Unpack parameters
    learning_rate = params['learning_rate']
    dropout_rate = params['dropout_rate']
    weight_decay = params['weight_decay']
    batch_size = params['batch_size']
    epochs = params['epochs']

    # Prepare data loaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

    # Model, criterion, and optimizer setup
    model = DNN_Dropout(dropout_rate=dropout_rate).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    # Use the previously implemented function for training and validation
    train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(
        model, train_loader, test_loader, criterion, optimizer, epochs, device
    )

    # Optional: Return more detailed training/validation outcomes
    return {
        "train_losses": train_losses,
        "train_accuracies": train_accuracies,
        "validation_losses": validation_losses,
        "validation_accuracies": validation_accuracies,
        "best_validation_accuracy": max(validation_accuracies)  # Assumes validation_accuracies is not empty
    }

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
#
# With this single, parameterized function, we encapsulate model training and validation, to streamline the workflow, and quickly iterate over various hyperparameters.
# </span>

# %% [markdown]
# ## Define the hyperparameter grid

# %%
# Example hyperparameter grid
param_space = {
    'epochs': [20, 30, 50],
    'batch_size': [128, 64, 32],
    'learning_rate': [0.01, 0.001, 0.0001],
    'weight_decay': [1e-4, 1e-5, 1e-6],
    'dropout_rate': [0.0, 0.2, 0.4, 0.6],
}

# %% [markdown]
# #### Code Breakdown
#
# ```python
# param_space = {
#     'epochs': [10, 20, 30],
#     'batch_size': [128, 64, 32],
#     'learning_rate': [0.01, 0.001, 0.0001],
#     'weight_decay': [1e-4, 1e-5, 1e-6],
#     'dropout_rate': [0.0, 0.2, 0.4, 0.6],
# }
# ```
#
# - The `param_space` dictionary defines a hyperparameter space with multiple values for each key parameter, including the number of epochs, batch size, learning rate, weight decay, and dropout rate.

# %% [markdown]
# ## Implement grid search
#
# Let's apply a structured approach for exploring a broad spectrum of hyperparameters using a **grid search** strategy. In a grid search, we systematically work through all the combinations of parameter values, cross-validating as we go to determine which tune yields the highest performance measure.
#
# - **Advantages:** This exhaustive search over specified parameter values provides a comprehensive overview of how different hyperparameters impact the performance, helping to identify the most promising configurations.
#
# - **Challenges:** The primary challenge with grid search is its computational cost. As the number of hyperparameters and their potential values increases, the total number of configurations grows exponentially. This can make grid searches computationally expensive and time-consuming, especially when training deep learning models.

# %%
# Generate all combinations of hyperparameters
param_grid = list(product(*param_space.values()))

# Convert to list of dicts to facilitate passing to the training function
param_dicts = [dict(zip(param_space.keys(), combo)) for combo in param_grid]
print(f"Number of parameters combinations: {len(param_dicts)} \n")

best_accuracy = 0
best_params = None
best_model_metrics = None

for params in param_dicts:
    model_metrics = train_validate_model(params, device)
    validation_accuracy = model_metrics['validation_accuracies'][-1]
    print(f"Validation accuracy: {validation_accuracy}\n")
    
    if validation_accuracy > best_accuracy:
        best_accuracy = validation_accuracy
        best_params = params
        best_model_metrics = model_metrics

    if best_accuracy > 0:
        print("\nIt looks like a very time and resource consuming strategy... \nLet's look for a smarter apporach!")
        break

print(f"Best Accuracy: {best_accuracy}")
print(f"Best Hyperparameters: {best_params}")
# Out:
# Number of parameters combinations: 324
#
# {'epochs': 20, 'batch_size': 128, 'learning_rate': 0.01, 'weight_decay': 0.0001, 'dropout_rate': 0.0}
#
# Epoch [1/20], Training Loss: 2.0147, Training Accuracy: 25.44%, Validation Loss: 1.9701, Validation Accuracy: 29.30%
# Epoch [2/20], Training Loss: 1.8277, Training Accuracy: 32.54%, Validation Loss: 1.9000, Validation Accuracy: 32.32%
# Epoch [3/20], Training Loss: 1.7513, Training Accuracy: 35.56%, Validation Loss: 1.8215, Validation Accuracy: 33.21%
# Epoch [4/20], Training Loss: 1.6387, Training Accuracy: 40.24%, Validation Loss: 1.9017, Validation Accuracy: 32.00%
# Epoch [5/20], Training Loss: 1.6822, Training Accuracy: 39.14%, Validation Loss: 1.8817, Validation Accuracy: 33.47%
# Epoch [6/20], Training Loss: 1.6430, Training Accuracy: 40.00%, Validation Loss: 1.7394, Validation Accuracy: 37.97%
# Epoch [7/20], Training Loss: 1.5108, Training Accuracy: 45.22%, Validation Loss: 1.8019, Validation Accuracy: 37.39%
# Epoch [8/20], Training Loss: 1.5323, Training Accuracy: 44.38%, Validation Loss: 1.7973, Validation Accuracy: 36.99%
# Epoch [9/20], Training Loss: 1.4898, Training Accuracy: 45.18%, Validation Loss: 1.7887, Validation Accuracy: 36.85%
# Epoch [10/20], Training Loss: 1.4405, Training Accuracy: 46.96%, Validation Loss: 1.8295, Validation Accuracy: 37.76%
# Epoch [11/20], Training Loss: 1.5208, Training Accuracy: 45.08%, Validation Loss: 1.8085, Validation Accuracy: 36.59%
# Epoch [12/20], Training Loss: 1.4708, Training Accuracy: 46.68%, Validation Loss: 1.7432, Validation Accuracy: 39.50%
# Epoch [13/20], Training Loss: 1.3982, Training Accuracy: 50.32%, Validation Loss: 1.8384, Validation Accuracy: 37.97%
# Epoch [14/20], Training Loss: 1.4143, Training Accuracy: 48.10%, Validation Loss: 1.7311, Validation Accuracy: 40.19%
# Epoch [15/20], Training Loss: 1.3624, Training Accuracy: 50.84%, Validation Loss: 1.7508, Validation Accuracy: 38.51%
# Epoch [16/20], Training Loss: 1.3443, Training Accuracy: 51.96%, Validation Loss: 1.7830, Validation Accuracy: 38.51%
# Epoch [17/20], Training Loss: 1.3577, Training Accuracy: 51.54%, Validation Loss: 1.7294, Validation Accuracy: 40.38%
# Epoch [18/20], Training Loss: 1.2777, Training Accuracy: 54.32%, Validation Loss: 1.8507, Validation Accuracy: 37.62%
# Epoch [19/20], Training Loss: 1.3092, Training Accuracy: 53.10%, Validation Loss: 1.7532, Validation Accuracy: 40.37%
# Epoch [20/20], Training Loss: 1.2560, Training Accuracy: 54.26%, Validation Loss: 1.8335, Validation Accuracy: 39.07%
#
# Execution time: 01:11
# Validation accuracy: 39.07
#
#
# It looks like a very time and resource consuming strategy...
# Let's look for a smarter apporach!
# Best Accuracy: 39.07
# Best Hyperparameters: {'epochs': 20, 'batch_size': 128, 'learning_rate': 0.01, 'weight_decay': 0.0001, 'dropout_rate': 0.0}

# %% [markdown]
# ## Implement random search
#
# Grid search is thorough and guarantees that you'll explore the entire specified parameter space, making it preferable when the search space is reasonably small and computational resources permit exhaustive search.
#
# Random search, is potentially more efficient in very large search spaces, but it might miss important combinations of parameters that could yield the best model performance.

# %%
def sample_hyperparameters(space):
    sampled_params = {}
    for k, v in space.items():
        sampled_params[k] = random.choice(v)
    return sampled_params

# Number of different models search for random search
num_searches = 10 

best_accuracy = 0
best_params = None
best_model_metrics = None

for n_search in range(num_searches):
    print(f"Search {n_search} out of {num_searches}")
    params = sample_hyperparameters(param_space)

    model_metrics = train_validate_model(params, device)
    validation_accuracy = model_metrics['validation_accuracies'][-1]
    print(f"Validation accuracy: {validation_accuracy}\n")
    
    if validation_accuracy > best_accuracy:
        best_accuracy = validation_accuracy
        best_params = params
        best_model_metrics = model_metrics

print(f"Best Accuracy: {best_accuracy}")
print(f"Best Hyperparameters: {best_params}")
# Out:
# Search 0 out of 10
# {'epochs': 50, 'batch_size': 128, 'learning_rate': 0.01, 'weight_decay': 1e-06, 'dropout_rate': 0.4}
#
# Epoch [1/50], Training Loss: 2.1544, Training Accuracy: 20.68%, Validation Loss: 2.0006, Validation Accuracy: 27.37%
# Epoch [2/50], Training Loss: 2.0153, Training Accuracy: 25.06%, Validation Loss: 1.9102, Validation Accuracy: 29.78%
# Epoch [3/50], Training Loss: 1.9158, Training Accuracy: 28.56%, Validation Loss: 1.8378, Validation Accuracy: 31.82%
# Epoch [4/50], Training Loss: 1.8865, Training Accuracy: 30.76%, Validation Loss: 1.7940, Validation Accuracy: 33.58%
# Epoch [5/50], Training Loss: 1.8324, Training Accuracy: 32.56%, Validation Loss: 1.7864, Validation Accuracy: 35.01%
# Epoch [6/50], Training Loss: 1.7951, Training Accuracy: 33.90%, Validation Loss: 1.7471, Validation Accuracy: 36.43%
# Epoch [7/50], Training Loss: 1.7628, Training Accuracy: 34.90%, Validation Loss: 1.7348, Validation Accuracy: 36.65%
# Epoch [8/50], Training Loss: 1.7139, Training Accuracy: 37.60%, Validation Loss: 1.7059, Validation Accuracy: 38.57%
# Epoch [9/50], Training Loss: 1.6567, Training Accuracy: 38.62%, Validation Loss: 1.7259, Validation Accuracy: 38.17%
# Epoch [10/50], Training Loss: 1.6957, Training Accuracy: 39.08%, Validation Loss: 1.6767, Validation Accuracy: 39.08%
# Epoch [11/50], Training Loss: 1.6258, Training Accuracy: 41.68%, Validation Loss: 1.6595, Validation Accuracy: 40.09%
# Epoch [12/50], Training Loss: 1.5957, Training Accuracy: 41.30%, Validation Loss: 1.6660, Validation Accuracy: 40.18%
# Epoch [13/50], Training Loss: 1.5651, Training Accuracy: 44.34%, Validation Loss: 1.6822, Validation Accuracy: 40.66%
# Epoch [14/50], Training Loss: 1.5631, Training Accuracy: 42.48%, Validation Loss: 1.6644, Validation Accuracy: 40.66%
# Epoch [15/50], Training Loss: 1.5321, Training Accuracy: 45.84%, Validation Loss: 1.6702, Validation Accuracy: 40.11%
# Epoch [16/50], Training Loss: 1.4809, Training Accuracy: 46.52%, Validation Loss: 1.7211, Validation Accuracy: 40.64%
# Epoch [17/50], Training Loss: 1.5631, Training Accuracy: 44.30%, Validation Loss: 1.6646, Validation Accuracy: 40.88%
# Epoch [18/50], Training Loss: 1.5059, Training Accuracy: 46.84%, Validation Loss: 1.6586, Validation Accuracy: 42.02%
# Epoch [19/50], Training Loss: 1.4960, Training Accuracy: 46.74%, Validation Loss: 1.6678, Validation Accuracy: 40.85%
# Epoch [20/50], Training Loss: 1.5520, Training Accuracy: 45.36%, Validation Loss: 1.6623, Validation Accuracy: 41.04%
# Epoch [21/50], Training Loss: 1.4777, Training Accuracy: 47.12%, Validation Loss: 1.6999, Validation Accuracy: 41.23%
# Epoch [22/50], Training Loss: 1.4527, Training Accuracy: 48.32%, Validation Loss: 1.6682, Validation Accuracy: 41.87%
# Epoch [23/50], Training Loss: 1.4434, Training Accuracy: 48.74%, Validation Loss: 1.6639, Validation Accuracy: 42.61%
# Epoch [24/50], Training Loss: 1.4510, Training Accuracy: 47.54%, Validation Loss: 1.6543, Validation Accuracy: 42.02%
# Epoch [25/50], Training Loss: 1.4292, Training Accuracy: 49.56%, Validation Loss: 1.6538, Validation Accuracy: 42.76%
# Epoch [26/50], Training Loss: 1.3898, Training Accuracy: 51.92%, Validation Loss: 1.6827, Validation Accuracy: 41.79%
# Epoch [27/50], Training Loss: 1.3558, Training Accuracy: 51.70%, Validation Loss: 1.6553, Validation Accuracy: 43.45%
# Epoch [28/50], Training Loss: 1.3017, Training Accuracy: 54.08%, Validation Loss: 1.6663, Validation Accuracy: 42.63%
# Epoch [29/50], Training Loss: 1.3142, Training Accuracy: 53.46%, Validation Loss: 1.6564, Validation Accuracy: 43.04%
# Epoch [30/50], Training Loss: 1.3093, Training Accuracy: 54.04%, Validation Loss: 1.6787, Validation Accuracy: 42.52%
# Epoch [31/50], Training Loss: 1.3014, Training Accuracy: 54.02%, Validation Loss: 1.6575, Validation Accuracy: 42.99%
# Epoch [32/50], Training Loss: 1.2368, Training Accuracy: 55.42%, Validation Loss: 1.7010, Validation Accuracy: 43.66%
# Epoch [33/50], Training Loss: 1.2626, Training Accuracy: 55.08%, Validation Loss: 1.6850, Validation Accuracy: 43.67%
# Epoch [34/50], Training Loss: 1.2491, Training Accuracy: 55.82%, Validation Loss: 1.6684, Validation Accuracy: 43.21%
# Epoch [35/50], Training Loss: 1.2387, Training Accuracy: 56.98%, Validation Loss: 1.7165, Validation Accuracy: 42.80%
# Epoch [36/50], Training Loss: 1.2749, Training Accuracy: 55.14%, Validation Loss: 1.6744, Validation Accuracy: 42.65%
# Epoch [37/50], Training Loss: 1.2591, Training Accuracy: 56.12%, Validation Loss: 1.6603, Validation Accuracy: 43.68%
# Epoch [38/50], Training Loss: 1.1962, Training Accuracy: 58.02%, Validation Loss: 1.6962, Validation Accuracy: 43.63%
# Epoch [39/50], Training Loss: 1.1670, Training Accuracy: 60.12%, Validation Loss: 1.7544, Validation Accuracy: 42.93%
# Epoch [40/50], Training Loss: 1.1507, Training Accuracy: 60.44%, Validation Loss: 1.7825, Validation Accuracy: 44.35%
# Epoch [41/50], Training Loss: 1.1983, Training Accuracy: 58.02%, Validation Loss: 1.7412, Validation Accuracy: 41.90%
# Epoch [42/50], Training Loss: 1.1941, Training Accuracy: 58.74%, Validation Loss: 1.7084, Validation Accuracy: 43.16%
# Epoch [43/50], Training Loss: 1.1938, Training Accuracy: 58.22%, Validation Loss: 1.7124, Validation Accuracy: 42.56%
# Epoch [44/50], Training Loss: 1.1261, Training Accuracy: 61.30%, Validation Loss: 1.7056, Validation Accuracy: 43.81%
# Epoch [45/50], Training Loss: 1.0693, Training Accuracy: 62.82%, Validation Loss: 1.7916, Validation Accuracy: 43.50%
# Epoch [46/50], Training Loss: 1.1600, Training Accuracy: 59.62%, Validation Loss: 1.7671, Validation Accuracy: 43.45%
# Epoch [47/50], Training Loss: 1.1235, Training Accuracy: 60.60%, Validation Loss: 1.7453, Validation Accuracy: 43.59%
# Epoch [48/50], Training Loss: 1.1380, Training Accuracy: 59.96%, Validation Loss: 1.7178, Validation Accuracy: 43.38%
# Epoch [49/50], Training Loss: 1.0526, Training Accuracy: 64.56%, Validation Loss: 1.7768, Validation Accuracy: 43.10%
# Epoch [50/50], Training Loss: 1.0923, Training Accuracy: 62.58%, Validation Loss: 1.7734, Validation Accuracy: 43.29%
#
# Execution time: 03:12
# Validation accuracy: 43.29
#
# Search 1 out of 10
# {'epochs': 20, 'batch_size': 128, 'learning_rate': 0.01, 'weight_decay': 1e-06, 'dropout_rate': 0.0}
#
# Epoch [1/20], Training Loss: 1.9958, Training Accuracy: 25.62%, Validation Loss: 1.9071, Validation Accuracy: 31.71%
# Epoch [2/20], Training Loss: 1.7893, Training Accuracy: 34.72%, Validation Loss: 1.8834, Validation Accuracy: 32.16%
# Epoch [3/20], Training Loss: 1.7354, Training Accuracy: 37.22%, Validation Loss: 1.8175, Validation Accuracy: 35.37%
# Epoch [4/20], Training Loss: 1.6537, Training Accuracy: 40.08%, Validation Loss: 1.7726, Validation Accuracy: 36.50%
# Epoch [5/20], Training Loss: 1.5879, Training Accuracy: 42.02%, Validation Loss: 1.7882, Validation Accuracy: 36.97%
# Epoch [6/20], Training Loss: 1.4751, Training Accuracy: 46.38%, Validation Loss: 1.7498, Validation Accuracy: 38.65%
# Epoch [7/20], Training Loss: 1.3891, Training Accuracy: 49.92%, Validation Loss: 1.7890, Validation Accuracy: 39.68%
# Epoch [8/20], Training Loss: 1.3375, Training Accuracy: 51.52%, Validation Loss: 1.8744, Validation Accuracy: 37.77%
# Epoch [9/20], Training Loss: 1.2586, Training Accuracy: 53.90%, Validation Loss: 2.0418, Validation Accuracy: 35.04%
# Epoch [10/20], Training Loss: 1.3405, Training Accuracy: 52.36%, Validation Loss: 1.8648, Validation Accuracy: 38.04%
# Epoch [11/20], Training Loss: 1.2576, Training Accuracy: 54.58%, Validation Loss: 1.9303, Validation Accuracy: 38.42%
# Epoch [12/20], Training Loss: 1.1199, Training Accuracy: 59.18%, Validation Loss: 1.8888, Validation Accuracy: 41.07%
# Epoch [13/20], Training Loss: 1.0404, Training Accuracy: 62.40%, Validation Loss: 2.0083, Validation Accuracy: 39.08%
# Epoch [14/20], Training Loss: 1.0777, Training Accuracy: 61.50%, Validation Loss: 1.9794, Validation Accuracy: 38.95%
# Epoch [15/20], Training Loss: 1.1101, Training Accuracy: 61.04%, Validation Loss: 2.0996, Validation Accuracy: 37.75%
# Epoch [16/20], Training Loss: 0.9887, Training Accuracy: 64.56%, Validation Loss: 2.0763, Validation Accuracy: 39.04%
# Epoch [17/20], Training Loss: 0.8896, Training Accuracy: 68.54%, Validation Loss: 2.0156, Validation Accuracy: 41.45%
# Epoch [18/20], Training Loss: 0.9342, Training Accuracy: 67.66%, Validation Loss: 2.2276, Validation Accuracy: 39.04%
# Epoch [19/20], Training Loss: 0.9415, Training Accuracy: 67.46%, Validation Loss: 2.0713, Validation Accuracy: 40.03%
# Epoch [20/20], Training Loss: 0.8534, Training Accuracy: 69.80%, Validation Loss: 2.0465, Validation Accuracy: 39.64%
#
# Execution time: 01:17
# Validation accuracy: 39.64
#
# Search 2 out of 10
# {'epochs': 50, 'batch_size': 32, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'dropout_rate': 0.6}
#
# Epoch [1/50], Training Loss: 2.4788, Training Accuracy: 9.82%, Validation Loss: 2.2885, Validation Accuracy: 10.84%
# Epoch [2/50], Training Loss: 2.4177, Training Accuracy: 10.22%, Validation Loss: 2.2717, Validation Accuracy: 15.37%
# Epoch [3/50], Training Loss: 2.3921, Training Accuracy: 11.26%, Validation Loss: 2.2588, Validation Accuracy: 19.01%
# Epoch [4/50], Training Loss: 2.3653, Training Accuracy: 12.02%, Validation Loss: 2.2328, Validation Accuracy: 18.79%
# Epoch [5/50], Training Loss: 2.3406, Training Accuracy: 12.90%, Validation Loss: 2.2081, Validation Accuracy: 20.14%
# Epoch [6/50], Training Loss: 2.2998, Training Accuracy: 14.48%, Validation Loss: 2.1861, Validation Accuracy: 22.09%
# Epoch [7/50], Training Loss: 2.2792, Training Accuracy: 13.88%, Validation Loss: 2.1583, Validation Accuracy: 22.83%
# Epoch [8/50], Training Loss: 2.2312, Training Accuracy: 16.52%, Validation Loss: 2.1383, Validation Accuracy: 22.93%
# Epoch [9/50], Training Loss: 2.2233, Training Accuracy: 16.86%, Validation Loss: 2.1287, Validation Accuracy: 24.21%
# Epoch [10/50], Training Loss: 2.2065, Training Accuracy: 17.32%, Validation Loss: 2.0979, Validation Accuracy: 25.60%
# Epoch [11/50], Training Loss: 2.1837, Training Accuracy: 18.52%, Validation Loss: 2.0797, Validation Accuracy: 26.09%
# Epoch [12/50], Training Loss: 2.1610, Training Accuracy: 18.98%, Validation Loss: 2.0514, Validation Accuracy: 26.38%
# Epoch [13/50], Training Loss: 2.1571, Training Accuracy: 19.22%, Validation Loss: 2.0445, Validation Accuracy: 27.96%
# Epoch [14/50], Training Loss: 2.1247, Training Accuracy: 20.40%, Validation Loss: 2.0193, Validation Accuracy: 27.48%
# Epoch [15/50], Training Loss: 2.1169, Training Accuracy: 20.12%, Validation Loss: 2.0110, Validation Accuracy: 27.03%
# Epoch [16/50], Training Loss: 2.0898, Training Accuracy: 21.56%, Validation Loss: 1.9854, Validation Accuracy: 26.76%
# Epoch [17/50], Training Loss: 2.0604, Training Accuracy: 22.38%, Validation Loss: 1.9770, Validation Accuracy: 27.57%
# Epoch [18/50], Training Loss: 2.0669, Training Accuracy: 22.16%, Validation Loss: 1.9600, Validation Accuracy: 26.75%
# Epoch [19/50], Training Loss: 2.0373, Training Accuracy: 23.38%, Validation Loss: 1.9461, Validation Accuracy: 28.57%
# Epoch [20/50], Training Loss: 2.0284, Training Accuracy: 23.24%, Validation Loss: 1.9250, Validation Accuracy: 28.69%
# Epoch [21/50], Training Loss: 2.0098, Training Accuracy: 25.18%, Validation Loss: 1.9168, Validation Accuracy: 29.90%
# Epoch [22/50], Training Loss: 2.0008, Training Accuracy: 24.82%, Validation Loss: 1.9042, Validation Accuracy: 30.43%
# Epoch [23/50], Training Loss: 1.9907, Training Accuracy: 24.80%, Validation Loss: 1.8945, Validation Accuracy: 29.81%
# Epoch [24/50], Training Loss: 1.9751, Training Accuracy: 25.14%, Validation Loss: 1.8914, Validation Accuracy: 30.35%
# Epoch [25/50], Training Loss: 1.9616, Training Accuracy: 25.90%, Validation Loss: 1.8714, Validation Accuracy: 31.13%
# Epoch [26/50], Training Loss: 1.9572, Training Accuracy: 26.12%, Validation Loss: 1.8646, Validation Accuracy: 31.00%
# Epoch [27/50], Training Loss: 1.9439, Training Accuracy: 25.24%, Validation Loss: 1.8569, Validation Accuracy: 31.09%
# Epoch [28/50], Training Loss: 1.9238, Training Accuracy: 27.02%, Validation Loss: 1.8398, Validation Accuracy: 31.12%
# Epoch [29/50], Training Loss: 1.9170, Training Accuracy: 27.00%, Validation Loss: 1.8289, Validation Accuracy: 31.43%
# Epoch [30/50], Training Loss: 1.9173, Training Accuracy: 27.26%, Validation Loss: 1.8371, Validation Accuracy: 31.33%
# Epoch [31/50], Training Loss: 1.8946, Training Accuracy: 26.98%, Validation Loss: 1.8245, Validation Accuracy: 32.31%
# Epoch [32/50], Training Loss: 1.8884, Training Accuracy: 27.18%, Validation Loss: 1.8161, Validation Accuracy: 31.95%
# Epoch [33/50], Training Loss: 1.8733, Training Accuracy: 28.12%, Validation Loss: 1.8196, Validation Accuracy: 31.61%
# Epoch [34/50], Training Loss: 1.8570, Training Accuracy: 29.08%, Validation Loss: 1.8060, Validation Accuracy: 32.06%
# Epoch [35/50], Training Loss: 1.8432, Training Accuracy: 29.50%, Validation Loss: 1.8024, Validation Accuracy: 33.14%
# Epoch [36/50], Training Loss: 1.8450, Training Accuracy: 29.64%, Validation Loss: 1.7882, Validation Accuracy: 33.20%
# Epoch [37/50], Training Loss: 1.8335, Training Accuracy: 29.06%, Validation Loss: 1.7921, Validation Accuracy: 32.77%
# Epoch [38/50], Training Loss: 1.8288, Training Accuracy: 30.72%, Validation Loss: 1.8135, Validation Accuracy: 32.19%
# Epoch [39/50], Training Loss: 1.8127, Training Accuracy: 30.50%, Validation Loss: 1.7846, Validation Accuracy: 32.91%
# Epoch [40/50], Training Loss: 1.8041, Training Accuracy: 31.34%, Validation Loss: 1.7819, Validation Accuracy: 34.20%
# Epoch [41/50], Training Loss: 1.7951, Training Accuracy: 31.84%, Validation Loss: 1.7742, Validation Accuracy: 34.13%
# Epoch [42/50], Training Loss: 1.7846, Training Accuracy: 32.18%, Validation Loss: 1.7770, Validation Accuracy: 33.94%
# Epoch [43/50], Training Loss: 1.7568, Training Accuracy: 32.74%, Validation Loss: 1.7639, Validation Accuracy: 34.39%
# Epoch [44/50], Training Loss: 1.7584, Training Accuracy: 32.12%, Validation Loss: 1.7668, Validation Accuracy: 34.54%
# Epoch [45/50], Training Loss: 1.7409, Training Accuracy: 33.32%, Validation Loss: 1.7582, Validation Accuracy: 34.82%
# Epoch [46/50], Training Loss: 1.7514, Training Accuracy: 32.66%, Validation Loss: 1.7539, Validation Accuracy: 35.29%
# Epoch [47/50], Training Loss: 1.7373, Training Accuracy: 34.22%, Validation Loss: 1.7480, Validation Accuracy: 34.71%
# Epoch [48/50], Training Loss: 1.7376, Training Accuracy: 33.08%, Validation Loss: 1.7500, Validation Accuracy: 35.62%
# Epoch [49/50], Training Loss: 1.7239, Training Accuracy: 33.86%, Validation Loss: 1.7412, Validation Accuracy: 35.96%
# Epoch [50/50], Training Loss: 1.6969, Training Accuracy: 36.22%, Validation Loss: 1.7311, Validation Accuracy: 36.27%
#
# Execution time: 03:33
# Validation accuracy: 36.27
#
# Search 3 out of 10
# {'epochs': 20, 'batch_size': 128, 'learning_rate': 0.01, 'weight_decay': 0.0001, 'dropout_rate': 0.2}
#
# Epoch [1/20], Training Loss: 2.0722, Training Accuracy: 24.14%, Validation Loss: 1.9475, Validation Accuracy: 27.66%
# Epoch [2/20], Training Loss: 1.8988, Training Accuracy: 30.24%, Validation Loss: 1.8136, Validation Accuracy: 33.93%
# Epoch [3/20], Training Loss: 1.8229, Training Accuracy: 32.40%, Validation Loss: 1.8027, Validation Accuracy: 35.00%
# Epoch [4/20], Training Loss: 1.7689, Training Accuracy: 35.20%, Validation Loss: 1.8204, Validation Accuracy: 33.97%
# Epoch [5/20], Training Loss: 1.7232, Training Accuracy: 36.36%, Validation Loss: 1.8463, Validation Accuracy: 34.79%
# Epoch [6/20], Training Loss: 1.7655, Training Accuracy: 35.54%, Validation Loss: 1.7975, Validation Accuracy: 35.94%
# Epoch [7/20], Training Loss: 1.6722, Training Accuracy: 39.48%, Validation Loss: 1.7508, Validation Accuracy: 36.62%
# Epoch [8/20], Training Loss: 1.7033, Training Accuracy: 38.46%, Validation Loss: 1.7639, Validation Accuracy: 36.16%
# Epoch [9/20], Training Loss: 1.6731, Training Accuracy: 39.66%, Validation Loss: 1.7522, Validation Accuracy: 38.54%
# Epoch [10/20], Training Loss: 1.6570, Training Accuracy: 39.78%, Validation Loss: 1.8285, Validation Accuracy: 34.86%
# Epoch [11/20], Training Loss: 1.6476, Training Accuracy: 40.70%, Validation Loss: 1.7707, Validation Accuracy: 35.96%
# Epoch [12/20], Training Loss: 1.6345, Training Accuracy: 40.68%, Validation Loss: 1.7525, Validation Accuracy: 37.90%
# Epoch [13/20], Training Loss: 1.6334, Training Accuracy: 41.66%, Validation Loss: 1.7916, Validation Accuracy: 36.73%
# Epoch [14/20], Training Loss: 1.6326, Training Accuracy: 40.86%, Validation Loss: 1.7660, Validation Accuracy: 35.54%
# Epoch [15/20], Training Loss: 1.5877, Training Accuracy: 42.98%, Validation Loss: 1.7947, Validation Accuracy: 36.49%
# Epoch [16/20], Training Loss: 1.5727, Training Accuracy: 43.26%, Validation Loss: 1.7881, Validation Accuracy: 35.34%
# Epoch [17/20], Training Loss: 1.6040, Training Accuracy: 42.40%, Validation Loss: 1.8257, Validation Accuracy: 36.07%
# Epoch [18/20], Training Loss: 1.6736, Training Accuracy: 40.26%, Validation Loss: 1.6924, Validation Accuracy: 39.70%
# Epoch [19/20], Training Loss: 1.5970, Training Accuracy: 43.02%, Validation Loss: 1.7298, Validation Accuracy: 38.02%
# Epoch [20/20], Training Loss: 1.5926, Training Accuracy: 42.76%, Validation Loss: 1.7455, Validation Accuracy: 38.44%
#
# Execution time: 01:06
# Validation accuracy: 38.44
#
# Search 4 out of 10
# {'epochs': 50, 'batch_size': 32, 'learning_rate': 0.01, 'weight_decay': 1e-06, 'dropout_rate': 0.2}
#
# Epoch [1/50], Training Loss: 2.0835, Training Accuracy: 23.36%, Validation Loss: 1.9326, Validation Accuracy: 27.87%
# Epoch [2/50], Training Loss: 1.9064, Training Accuracy: 30.60%, Validation Loss: 1.8340, Validation Accuracy: 33.77%
# Epoch [3/50], Training Loss: 1.8257, Training Accuracy: 33.42%, Validation Loss: 1.7756, Validation Accuracy: 35.06%
# Epoch [4/50], Training Loss: 1.7841, Training Accuracy: 35.48%, Validation Loss: 1.7399, Validation Accuracy: 36.52%
# Epoch [5/50], Training Loss: 1.7190, Training Accuracy: 36.62%, Validation Loss: 1.7304, Validation Accuracy: 37.24%
# Epoch [6/50], Training Loss: 1.6785, Training Accuracy: 38.50%, Validation Loss: 1.7282, Validation Accuracy: 38.06%
# Epoch [7/50], Training Loss: 1.6116, Training Accuracy: 41.72%, Validation Loss: 1.6762, Validation Accuracy: 39.57%
# Epoch [8/50], Training Loss: 1.5882, Training Accuracy: 42.40%, Validation Loss: 1.6659, Validation Accuracy: 40.08%
# Epoch [9/50], Training Loss: 1.5362, Training Accuracy: 44.70%, Validation Loss: 1.7111, Validation Accuracy: 38.19%
# Epoch [10/50], Training Loss: 1.5062, Training Accuracy: 45.48%, Validation Loss: 1.6849, Validation Accuracy: 40.93%
# Epoch [11/50], Training Loss: 1.4841, Training Accuracy: 47.24%, Validation Loss: 1.6616, Validation Accuracy: 40.69%
# Epoch [12/50], Training Loss: 1.4319, Training Accuracy: 49.32%, Validation Loss: 1.6566, Validation Accuracy: 40.91%
# Epoch [13/50], Training Loss: 1.4186, Training Accuracy: 49.68%, Validation Loss: 1.6405, Validation Accuracy: 41.90%
# Epoch [14/50], Training Loss: 1.3630, Training Accuracy: 51.38%, Validation Loss: 1.7289, Validation Accuracy: 39.91%
# Epoch [15/50], Training Loss: 1.3346, Training Accuracy: 51.74%, Validation Loss: 1.6502, Validation Accuracy: 42.26%
# Epoch [16/50], Training Loss: 1.3175, Training Accuracy: 53.42%, Validation Loss: 1.6662, Validation Accuracy: 41.76%
# Epoch [17/50], Training Loss: 1.2904, Training Accuracy: 53.72%, Validation Loss: 1.7248, Validation Accuracy: 41.05%
# Epoch [18/50], Training Loss: 1.2618, Training Accuracy: 54.78%, Validation Loss: 1.7208, Validation Accuracy: 41.84%
# Epoch [19/50], Training Loss: 1.1918, Training Accuracy: 58.16%, Validation Loss: 1.7376, Validation Accuracy: 40.36%
# Epoch [20/50], Training Loss: 1.1774, Training Accuracy: 58.30%, Validation Loss: 1.7408, Validation Accuracy: 42.43%
# Epoch [21/50], Training Loss: 1.1596, Training Accuracy: 59.38%, Validation Loss: 1.7202, Validation Accuracy: 42.20%
# Epoch [22/50], Training Loss: 1.1172, Training Accuracy: 60.46%, Validation Loss: 1.7283, Validation Accuracy: 41.94%
# Epoch [23/50], Training Loss: 1.1118, Training Accuracy: 60.22%, Validation Loss: 1.8487, Validation Accuracy: 41.86%
# Epoch [24/50], Training Loss: 1.0797, Training Accuracy: 62.24%, Validation Loss: 1.7270, Validation Accuracy: 43.21%
# Epoch [25/50], Training Loss: 1.0650, Training Accuracy: 63.10%, Validation Loss: 1.8064, Validation Accuracy: 42.76%
# Epoch [26/50], Training Loss: 1.0359, Training Accuracy: 63.94%, Validation Loss: 1.7414, Validation Accuracy: 43.47%
# Epoch [27/50], Training Loss: 1.0292, Training Accuracy: 63.84%, Validation Loss: 1.7550, Validation Accuracy: 42.50%
# Epoch [28/50], Training Loss: 0.9956, Training Accuracy: 64.82%, Validation Loss: 1.8602, Validation Accuracy: 42.27%
# Epoch [29/50], Training Loss: 1.0055, Training Accuracy: 64.62%, Validation Loss: 1.8125, Validation Accuracy: 42.63%
# Epoch [30/50], Training Loss: 0.9573, Training Accuracy: 66.96%, Validation Loss: 1.8471, Validation Accuracy: 42.82%
# Epoch [31/50], Training Loss: 0.9579, Training Accuracy: 67.26%, Validation Loss: 1.8761, Validation Accuracy: 42.32%
# Epoch [32/50], Training Loss: 0.9324, Training Accuracy: 67.80%, Validation Loss: 1.8606, Validation Accuracy: 42.49%
# Epoch [33/50], Training Loss: 0.8763, Training Accuracy: 69.16%, Validation Loss: 1.8926, Validation Accuracy: 42.79%
# Epoch [34/50], Training Loss: 0.8568, Training Accuracy: 70.44%, Validation Loss: 1.8922, Validation Accuracy: 42.70%
# Epoch [35/50], Training Loss: 0.8772, Training Accuracy: 69.28%, Validation Loss: 2.0010, Validation Accuracy: 40.80%
# Epoch [36/50], Training Loss: 0.8470, Training Accuracy: 71.14%, Validation Loss: 1.9023, Validation Accuracy: 41.80%
# Epoch [37/50], Training Loss: 0.8441, Training Accuracy: 70.74%, Validation Loss: 1.8995, Validation Accuracy: 42.86%
# Epoch [38/50], Training Loss: 0.8201, Training Accuracy: 71.22%, Validation Loss: 1.8882, Validation Accuracy: 43.47%
# Epoch [39/50], Training Loss: 0.7932, Training Accuracy: 72.52%, Validation Loss: 1.9405, Validation Accuracy: 43.07%
# Epoch [40/50], Training Loss: 0.7717, Training Accuracy: 73.28%, Validation Loss: 1.9210, Validation Accuracy: 43.55%
# Epoch [41/50], Training Loss: 0.8002, Training Accuracy: 72.94%, Validation Loss: 1.9026, Validation Accuracy: 43.79%
# Epoch [42/50], Training Loss: 0.7375, Training Accuracy: 74.64%, Validation Loss: 2.0156, Validation Accuracy: 42.44%
# Epoch [43/50], Training Loss: 0.7713, Training Accuracy: 73.66%, Validation Loss: 2.0361, Validation Accuracy: 40.87%
# Epoch [44/50], Training Loss: 0.7431, Training Accuracy: 74.66%, Validation Loss: 1.8772, Validation Accuracy: 43.07%
# Epoch [45/50], Training Loss: 0.7080, Training Accuracy: 75.84%, Validation Loss: 2.0228, Validation Accuracy: 42.09%
# Epoch [46/50], Training Loss: 0.7083, Training Accuracy: 76.38%, Validation Loss: 2.0519, Validation Accuracy: 41.46%
# Epoch [47/50], Training Loss: 0.7311, Training Accuracy: 75.34%, Validation Loss: 2.0009, Validation Accuracy: 43.61%
# Epoch [48/50], Training Loss: 0.6728, Training Accuracy: 77.28%, Validation Loss: 2.0535, Validation Accuracy: 43.36%
# Epoch [49/50], Training Loss: 0.6917, Training Accuracy: 76.98%, Validation Loss: 2.0699, Validation Accuracy: 42.20%
# Epoch [50/50], Training Loss: 0.6737, Training Accuracy: 77.46%, Validation Loss: 2.0251, Validation Accuracy: 43.24%
#
# Execution time: 03:47
# Validation accuracy: 43.24
#
# Search 5 out of 10
# {'epochs': 50, 'batch_size': 32, 'learning_rate': 0.0001, 'weight_decay': 1e-06, 'dropout_rate': 0.6}
#
# Epoch [1/50], Training Loss: 2.4323, Training Accuracy: 10.86%, Validation Loss: 2.2877, Validation Accuracy: 12.56%
# Epoch [2/50], Training Loss: 2.4065, Training Accuracy: 11.04%, Validation Loss: 2.2726, Validation Accuracy: 15.44%
# Epoch [3/50], Training Loss: 2.3757, Training Accuracy: 11.54%, Validation Loss: 2.2583, Validation Accuracy: 16.61%
# Epoch [4/50], Training Loss: 2.3480, Training Accuracy: 12.30%, Validation Loss: 2.2308, Validation Accuracy: 21.13%
# Epoch [5/50], Training Loss: 2.3360, Training Accuracy: 13.20%, Validation Loss: 2.2176, Validation Accuracy: 20.05%
# Epoch [6/50], Training Loss: 2.3081, Training Accuracy: 13.58%, Validation Loss: 2.1979, Validation Accuracy: 20.76%
# Epoch [7/50], Training Loss: 2.2757, Training Accuracy: 14.82%, Validation Loss: 2.1752, Validation Accuracy: 21.92%
# Epoch [8/50], Training Loss: 2.2476, Training Accuracy: 15.92%, Validation Loss: 2.1379, Validation Accuracy: 22.20%
# Epoch [9/50], Training Loss: 2.2359, Training Accuracy: 15.94%, Validation Loss: 2.1459, Validation Accuracy: 21.84%
# Epoch [10/50], Training Loss: 2.2167, Training Accuracy: 17.02%, Validation Loss: 2.1236, Validation Accuracy: 22.40%
# Epoch [11/50], Training Loss: 2.1860, Training Accuracy: 17.58%, Validation Loss: 2.1044, Validation Accuracy: 23.48%
# Epoch [12/50], Training Loss: 2.1643, Training Accuracy: 18.82%, Validation Loss: 2.1009, Validation Accuracy: 23.60%
# Epoch [13/50], Training Loss: 2.1667, Training Accuracy: 18.78%, Validation Loss: 2.0705, Validation Accuracy: 25.19%
# Epoch [14/50], Training Loss: 2.1356, Training Accuracy: 20.14%, Validation Loss: 2.0594, Validation Accuracy: 24.72%
# Epoch [15/50], Training Loss: 2.1170, Training Accuracy: 20.14%, Validation Loss: 2.0357, Validation Accuracy: 26.09%
# Epoch [16/50], Training Loss: 2.1122, Training Accuracy: 20.34%, Validation Loss: 2.0212, Validation Accuracy: 25.98%
# Epoch [17/50], Training Loss: 2.0856, Training Accuracy: 21.38%, Validation Loss: 1.9977, Validation Accuracy: 26.98%
# Epoch [18/50], Training Loss: 2.0814, Training Accuracy: 21.00%, Validation Loss: 1.9754, Validation Accuracy: 28.05%
# Epoch [19/50], Training Loss: 2.0635, Training Accuracy: 22.44%, Validation Loss: 1.9594, Validation Accuracy: 27.99%
# Epoch [20/50], Training Loss: 2.0386, Training Accuracy: 23.60%, Validation Loss: 1.9659, Validation Accuracy: 27.88%
# Epoch [21/50], Training Loss: 2.0305, Training Accuracy: 23.68%, Validation Loss: 1.9477, Validation Accuracy: 28.84%
# Epoch [22/50], Training Loss: 2.0159, Training Accuracy: 24.18%, Validation Loss: 1.9026, Validation Accuracy: 30.71%
# Epoch [23/50], Training Loss: 2.0050, Training Accuracy: 24.76%, Validation Loss: 1.9287, Validation Accuracy: 29.47%
# Epoch [24/50], Training Loss: 1.9855, Training Accuracy: 24.30%, Validation Loss: 1.9047, Validation Accuracy: 29.68%
# Epoch [25/50], Training Loss: 1.9571, Training Accuracy: 25.48%, Validation Loss: 1.8864, Validation Accuracy: 30.73%
# Epoch [26/50], Training Loss: 1.9608, Training Accuracy: 25.58%, Validation Loss: 1.8835, Validation Accuracy: 30.62%
# Epoch [27/50], Training Loss: 1.9528, Training Accuracy: 26.22%, Validation Loss: 1.8904, Validation Accuracy: 30.88%
# Epoch [28/50], Training Loss: 1.9376, Training Accuracy: 26.80%, Validation Loss: 1.8754, Validation Accuracy: 30.45%
# Epoch [29/50], Training Loss: 1.9295, Training Accuracy: 26.76%, Validation Loss: 1.8732, Validation Accuracy: 31.10%
# Epoch [30/50], Training Loss: 1.9225, Training Accuracy: 27.50%, Validation Loss: 1.8671, Validation Accuracy: 31.23%
# Epoch [31/50], Training Loss: 1.8988, Training Accuracy: 29.02%, Validation Loss: 1.8429, Validation Accuracy: 32.12%
# Epoch [32/50], Training Loss: 1.8983, Training Accuracy: 28.48%, Validation Loss: 1.8476, Validation Accuracy: 31.20%
# Epoch [33/50], Training Loss: 1.8778, Training Accuracy: 29.04%, Validation Loss: 1.8653, Validation Accuracy: 31.21%
# Epoch [34/50], Training Loss: 1.8723, Training Accuracy: 29.28%, Validation Loss: 1.8359, Validation Accuracy: 32.62%
# Epoch [35/50], Training Loss: 1.8625, Training Accuracy: 29.84%, Validation Loss: 1.8363, Validation Accuracy: 33.23%
# Epoch [36/50], Training Loss: 1.8594, Training Accuracy: 30.54%, Validation Loss: 1.8073, Validation Accuracy: 34.05%
# Epoch [37/50], Training Loss: 1.8464, Training Accuracy: 30.66%, Validation Loss: 1.8155, Validation Accuracy: 33.02%
# Epoch [38/50], Training Loss: 1.8329, Training Accuracy: 31.04%, Validation Loss: 1.8022, Validation Accuracy: 33.58%
# Epoch [39/50], Training Loss: 1.8343, Training Accuracy: 31.00%, Validation Loss: 1.8187, Validation Accuracy: 33.02%
# Epoch [40/50], Training Loss: 1.8202, Training Accuracy: 31.74%, Validation Loss: 1.7875, Validation Accuracy: 34.19%
# Epoch [41/50], Training Loss: 1.8081, Training Accuracy: 31.20%, Validation Loss: 1.7836, Validation Accuracy: 35.03%
# Epoch [42/50], Training Loss: 1.7889, Training Accuracy: 32.98%, Validation Loss: 1.7972, Validation Accuracy: 34.51%
# Epoch [43/50], Training Loss: 1.7683, Training Accuracy: 32.86%, Validation Loss: 1.7688, Validation Accuracy: 35.71%
# Epoch [44/50], Training Loss: 1.7823, Training Accuracy: 32.84%, Validation Loss: 1.7879, Validation Accuracy: 35.11%
# Epoch [45/50], Training Loss: 1.7541, Training Accuracy: 34.58%, Validation Loss: 1.7882, Validation Accuracy: 34.57%
# Epoch [46/50], Training Loss: 1.7429, Training Accuracy: 34.60%, Validation Loss: 1.7909, Validation Accuracy: 35.17%
# Epoch [47/50], Training Loss: 1.7430, Training Accuracy: 35.32%, Validation Loss: 1.7516, Validation Accuracy: 37.28%
# Epoch [48/50], Training Loss: 1.7340, Training Accuracy: 35.18%, Validation Loss: 1.7445, Validation Accuracy: 37.15%
# Epoch [49/50], Training Loss: 1.7214, Training Accuracy: 35.10%, Validation Loss: 1.7558, Validation Accuracy: 36.76%
# Epoch [50/50], Training Loss: 1.7261, Training Accuracy: 36.06%, Validation Loss: 1.7514, Validation Accuracy: 37.11%
#
# Execution time: 03:52
# Validation accuracy: 37.11
#
# Search 6 out of 10
# {'epochs': 20, 'batch_size': 64, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'dropout_rate': 0.0}
#
# Epoch [1/20], Training Loss: 2.0666, Training Accuracy: 27.28%, Validation Loss: 1.9403, Validation Accuracy: 33.49%
# Epoch [2/20], Training Loss: 1.7844, Training Accuracy: 42.40%, Validation Loss: 1.8373, Validation Accuracy: 38.78%
# Epoch [3/20], Training Loss: 1.6167, Training Accuracy: 50.32%, Validation Loss: 1.7881, Validation Accuracy: 40.21%
# Epoch [4/20], Training Loss: 1.4657, Training Accuracy: 57.22%, Validation Loss: 1.7315, Validation Accuracy: 41.98%
# Epoch [5/20], Training Loss: 1.3144, Training Accuracy: 63.60%, Validation Loss: 1.6984, Validation Accuracy: 43.35%
# Epoch [6/20], Training Loss: 1.1836, Training Accuracy: 69.80%, Validation Loss: 1.6859, Validation Accuracy: 42.80%
# Epoch [7/20], Training Loss: 1.0695, Training Accuracy: 73.74%, Validation Loss: 1.6760, Validation Accuracy: 42.72%
# Epoch [8/20], Training Loss: 0.9375, Training Accuracy: 78.50%, Validation Loss: 1.6833, Validation Accuracy: 42.46%
# Epoch [9/20], Training Loss: 0.8195, Training Accuracy: 82.56%, Validation Loss: 1.6663, Validation Accuracy: 43.56%
# Epoch [10/20], Training Loss: 0.7414, Training Accuracy: 84.70%, Validation Loss: 1.7023, Validation Accuracy: 42.40%
# Epoch [11/20], Training Loss: 0.6610, Training Accuracy: 86.40%, Validation Loss: 1.6972, Validation Accuracy: 42.71%
# Epoch [12/20], Training Loss: 0.5450, Training Accuracy: 89.86%, Validation Loss: 1.7219, Validation Accuracy: 41.58%
# Epoch [13/20], Training Loss: 0.5115, Training Accuracy: 90.98%, Validation Loss: 1.7199, Validation Accuracy: 43.14%
# Epoch [14/20], Training Loss: 0.4774, Training Accuracy: 90.84%, Validation Loss: 1.8136, Validation Accuracy: 41.03%
# Epoch [15/20], Training Loss: 0.4008, Training Accuracy: 92.94%, Validation Loss: 1.7362, Validation Accuracy: 42.68%
# Epoch [16/20], Training Loss: 0.3227, Training Accuracy: 95.16%, Validation Loss: 1.8080, Validation Accuracy: 42.13%
# Epoch [17/20], Training Loss: 0.3094, Training Accuracy: 95.12%, Validation Loss: 1.8138, Validation Accuracy: 41.66%
# Epoch [18/20], Training Loss: 0.3095, Training Accuracy: 94.70%, Validation Loss: 1.8425, Validation Accuracy: 41.37%
# Epoch [19/20], Training Loss: 0.2685, Training Accuracy: 95.70%, Validation Loss: 1.8437, Validation Accuracy: 42.00%
# Epoch [20/20], Training Loss: 0.2921, Training Accuracy: 94.38%, Validation Loss: 1.8803, Validation Accuracy: 42.18%
#
# Execution time: 01:21
# Validation accuracy: 42.18
#
# Search 7 out of 10
# {'epochs': 20, 'batch_size': 32, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'dropout_rate': 0.4}
#
# Epoch [1/20], Training Loss: 2.2003, Training Accuracy: 18.56%, Validation Loss: 1.9894, Validation Accuracy: 27.80%
# Epoch [2/20], Training Loss: 2.0052, Training Accuracy: 25.86%, Validation Loss: 1.8659, Validation Accuracy: 32.62%
# Epoch [3/20], Training Loss: 1.9044, Training Accuracy: 30.22%, Validation Loss: 1.7999, Validation Accuracy: 34.48%
# Epoch [4/20], Training Loss: 1.8579, Training Accuracy: 32.94%, Validation Loss: 1.7432, Validation Accuracy: 36.91%
# Epoch [5/20], Training Loss: 1.7941, Training Accuracy: 34.88%, Validation Loss: 1.7229, Validation Accuracy: 38.25%
# Epoch [6/20], Training Loss: 1.7392, Training Accuracy: 37.70%, Validation Loss: 1.7155, Validation Accuracy: 37.51%
# Epoch [7/20], Training Loss: 1.7338, Training Accuracy: 37.66%, Validation Loss: 1.7191, Validation Accuracy: 37.83%
# Epoch [8/20], Training Loss: 1.6748, Training Accuracy: 39.68%, Validation Loss: 1.6705, Validation Accuracy: 40.07%
# Epoch [9/20], Training Loss: 1.6478, Training Accuracy: 41.66%, Validation Loss: 1.6789, Validation Accuracy: 39.71%
# Epoch [10/20], Training Loss: 1.6084, Training Accuracy: 41.72%, Validation Loss: 1.6624, Validation Accuracy: 40.25%
# Epoch [11/20], Training Loss: 1.5864, Training Accuracy: 43.98%, Validation Loss: 1.6507, Validation Accuracy: 40.62%
# Epoch [12/20], Training Loss: 1.5601, Training Accuracy: 44.74%, Validation Loss: 1.6622, Validation Accuracy: 40.09%
# Epoch [13/20], Training Loss: 1.5379, Training Accuracy: 45.22%, Validation Loss: 1.6303, Validation Accuracy: 41.61%
# Epoch [14/20], Training Loss: 1.5178, Training Accuracy: 45.06%, Validation Loss: 1.6539, Validation Accuracy: 41.39%
# Epoch [15/20], Training Loss: 1.4842, Training Accuracy: 46.44%, Validation Loss: 1.6398, Validation Accuracy: 41.86%
# Epoch [16/20], Training Loss: 1.4451, Training Accuracy: 48.42%, Validation Loss: 1.6729, Validation Accuracy: 40.20%
# Epoch [17/20], Training Loss: 1.4606, Training Accuracy: 48.42%, Validation Loss: 1.6470, Validation Accuracy: 41.06%
# Epoch [18/20], Training Loss: 1.4219, Training Accuracy: 49.44%, Validation Loss: 1.6600, Validation Accuracy: 41.88%
# Epoch [19/20], Training Loss: 1.4065, Training Accuracy: 50.48%, Validation Loss: 1.6364, Validation Accuracy: 42.70%
# Epoch [20/20], Training Loss: 1.3858, Training Accuracy: 50.14%, Validation Loss: 1.6172, Validation Accuracy: 43.01%
#
# Execution time: 01:35
# Validation accuracy: 43.01
#
# Search 8 out of 10
# {'epochs': 20, 'batch_size': 128, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'dropout_rate': 0.0}
#
# Epoch [1/20], Training Loss: 1.9536, Training Accuracy: 30.18%, Validation Loss: 1.8146, Validation Accuracy: 35.34%
# Epoch [2/20], Training Loss: 1.7163, Training Accuracy: 39.00%, Validation Loss: 1.7319, Validation Accuracy: 38.51%
# Epoch [3/20], Training Loss: 1.5735, Training Accuracy: 43.84%, Validation Loss: 1.7370, Validation Accuracy: 37.95%
# Epoch [4/20], Training Loss: 1.5068, Training Accuracy: 46.78%, Validation Loss: 1.6813, Validation Accuracy: 40.10%
# Epoch [5/20], Training Loss: 1.3966, Training Accuracy: 50.16%, Validation Loss: 1.6763, Validation Accuracy: 40.73%
# Epoch [6/20], Training Loss: 1.2926, Training Accuracy: 54.30%, Validation Loss: 1.6725, Validation Accuracy: 42.43%
# Epoch [7/20], Training Loss: 1.2277, Training Accuracy: 56.80%, Validation Loss: 1.7447, Validation Accuracy: 39.22%
# Epoch [8/20], Training Loss: 1.0998, Training Accuracy: 62.42%, Validation Loss: 1.8158, Validation Accuracy: 39.92%
# Epoch [9/20], Training Loss: 1.1127, Training Accuracy: 61.22%, Validation Loss: 1.7259, Validation Accuracy: 41.95%
# Epoch [10/20], Training Loss: 1.0134, Training Accuracy: 64.96%, Validation Loss: 1.8552, Validation Accuracy: 39.56%
# Epoch [11/20], Training Loss: 0.9227, Training Accuracy: 67.94%, Validation Loss: 1.7943, Validation Accuracy: 42.17%
# Epoch [12/20], Training Loss: 0.8927, Training Accuracy: 69.62%, Validation Loss: 1.8592, Validation Accuracy: 40.24%
# Epoch [13/20], Training Loss: 0.8193, Training Accuracy: 71.86%, Validation Loss: 1.9324, Validation Accuracy: 41.12%
# Epoch [14/20], Training Loss: 0.7210, Training Accuracy: 75.64%, Validation Loss: 1.9501, Validation Accuracy: 40.71%
# Epoch [15/20], Training Loss: 0.8063, Training Accuracy: 72.06%, Validation Loss: 1.9903, Validation Accuracy: 40.72%
# Epoch [16/20], Training Loss: 0.7161, Training Accuracy: 75.88%, Validation Loss: 1.9193, Validation Accuracy: 41.90%
# Epoch [17/20], Training Loss: 0.5800, Training Accuracy: 80.46%, Validation Loss: 2.0166, Validation Accuracy: 41.64%
# Epoch [18/20], Training Loss: 0.5120, Training Accuracy: 83.60%, Validation Loss: 2.1203, Validation Accuracy: 40.46%
# Epoch [19/20], Training Loss: 0.7009, Training Accuracy: 76.86%, Validation Loss: 2.1789, Validation Accuracy: 39.08%
# Epoch [20/20], Training Loss: 0.5687, Training Accuracy: 80.62%, Validation Loss: 2.1005, Validation Accuracy: 41.52%
#
# Execution time: 01:10
# Validation accuracy: 41.52
#
# Search 9 out of 10
# {'epochs': 30, 'batch_size': 128, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'dropout_rate': 0.4}
#
# Epoch [1/30], Training Loss: 2.2555, Training Accuracy: 16.38%, Validation Loss: 2.0647, Validation Accuracy: 25.60%
# Epoch [2/30], Training Loss: 2.0758, Training Accuracy: 24.30%, Validation Loss: 1.9450, Validation Accuracy: 29.68%
# Epoch [3/30], Training Loss: 1.9851, Training Accuracy: 27.14%, Validation Loss: 1.8646, Validation Accuracy: 32.63%
# Epoch [4/30], Training Loss: 1.8855, Training Accuracy: 30.42%, Validation Loss: 1.8110, Validation Accuracy: 34.76%
# Epoch [5/30], Training Loss: 1.8212, Training Accuracy: 33.52%, Validation Loss: 1.7709, Validation Accuracy: 36.06%
# Epoch [6/30], Training Loss: 1.7806, Training Accuracy: 35.40%, Validation Loss: 1.7692, Validation Accuracy: 35.85%
# Epoch [7/30], Training Loss: 1.7915, Training Accuracy: 35.04%, Validation Loss: 1.7220, Validation Accuracy: 38.27%
# Epoch [8/30], Training Loss: 1.7220, Training Accuracy: 37.48%, Validation Loss: 1.6989, Validation Accuracy: 39.05%
# Epoch [9/30], Training Loss: 1.6969, Training Accuracy: 39.00%, Validation Loss: 1.6864, Validation Accuracy: 39.17%
# Epoch [10/30], Training Loss: 1.6690, Training Accuracy: 40.96%, Validation Loss: 1.6720, Validation Accuracy: 39.75%
# Epoch [11/30], Training Loss: 1.6279, Training Accuracy: 41.60%, Validation Loss: 1.6684, Validation Accuracy: 39.98%
# Epoch [12/30], Training Loss: 1.5839, Training Accuracy: 42.12%, Validation Loss: 1.6418, Validation Accuracy: 41.68%
# Epoch [13/30], Training Loss: 1.5583, Training Accuracy: 44.20%, Validation Loss: 1.6595, Validation Accuracy: 41.69%
# Epoch [14/30], Training Loss: 1.5287, Training Accuracy: 45.32%, Validation Loss: 1.6334, Validation Accuracy: 41.56%
# Epoch [15/30], Training Loss: 1.5069, Training Accuracy: 47.34%, Validation Loss: 1.6620, Validation Accuracy: 41.06%
# Epoch [16/30], Training Loss: 1.5343, Training Accuracy: 44.68%, Validation Loss: 1.6510, Validation Accuracy: 41.97%
# Epoch [17/30], Training Loss: 1.4939, Training Accuracy: 46.78%, Validation Loss: 1.6372, Validation Accuracy: 41.65%
# Epoch [18/30], Training Loss: 1.4822, Training Accuracy: 47.40%, Validation Loss: 1.6363, Validation Accuracy: 42.25%
# Epoch [19/30], Training Loss: 1.4072, Training Accuracy: 50.38%, Validation Loss: 1.6353, Validation Accuracy: 42.44%
# Epoch [20/30], Training Loss: 1.3863, Training Accuracy: 50.92%, Validation Loss: 1.6504, Validation Accuracy: 41.48%
# Epoch [21/30], Training Loss: 1.3943, Training Accuracy: 50.40%, Validation Loss: 1.6370, Validation Accuracy: 42.90%
# Epoch [22/30], Training Loss: 1.3499, Training Accuracy: 51.74%, Validation Loss: 1.6501, Validation Accuracy: 42.42%
# Epoch [23/30], Training Loss: 1.3319, Training Accuracy: 52.86%, Validation Loss: 1.6506, Validation Accuracy: 42.99%
# Epoch [24/30], Training Loss: 1.3278, Training Accuracy: 53.52%, Validation Loss: 1.6911, Validation Accuracy: 42.36%
# Epoch [25/30], Training Loss: 1.3176, Training Accuracy: 53.20%, Validation Loss: 1.6545, Validation Accuracy: 42.93%
# Epoch [26/30], Training Loss: 1.2673, Training Accuracy: 54.80%, Validation Loss: 1.6480, Validation Accuracy: 42.68%
# Epoch [27/30], Training Loss: 1.2990, Training Accuracy: 53.60%, Validation Loss: 1.6837, Validation Accuracy: 42.93%
# Epoch [28/30], Training Loss: 1.2969, Training Accuracy: 53.84%, Validation Loss: 1.6889, Validation Accuracy: 42.94%
# Epoch [29/30], Training Loss: 1.2432, Training Accuracy: 56.20%, Validation Loss: 1.6539, Validation Accuracy: 43.08%
# Epoch [30/30], Training Loss: 1.2071, Training Accuracy: 57.04%, Validation Loss: 1.7307, Validation Accuracy: 42.06%
#
# Execution time: 01:46
# Validation accuracy: 42.06
#
# Best Accuracy: 43.29
# Best Hyperparameters: {'epochs': 50, 'batch_size': 128, 'learning_rate': 0.01, 'weight_decay': 1e-06, 'dropout_rate': 0.4}

# %% [markdown]
# ## CNN
#
# Convolutional Neural Networks (CNNs) have revolutionized the field of image recognition. CNNs excel at capturing spatial relationships within image data through the use of convolutional filters. These filters allow CNNs to identify patterns and features at different spatial scales, making them particularly well-suited for tasks such as image classification.

# %%
class CNN(nn.Module):
    def __init__(self, dropout_rate = 0.2):
        super(CNN, self).__init__()
        self.dropout_rate = dropout_rate
        self.conv_layer = nn.Sequential(
            # Conv Layer block 1: 32x32x3 -> 16x16x32
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv Layer block 2: 16x16x32 -> 8x8x64
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.fc_layer = nn.Sequential(
            nn.Dropout(p=self.dropout_rate),
            nn.Linear(8*8*64, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, 10)
        )
        
    def forward(self, x):
        x = self.conv_layer(x)
        x = x.view(x.size(0), -1)  # Flatten the output for the fully connected layers
        x = self.fc_layer(x)
        return x

cnn_model = CNN().to(device)
print(cnn_model)
# Out:
# CNN(
#   (conv_layer): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU(inplace=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc_layer): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=4096, out_features=512, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
#
# CNNs are a cornerstone of modern deep learning, especially in tasks related to images.
#
# ```python
# class CNN(nn.Module):
#     def __init__(self, dropout_rate=0.2):
#         super(CNN, self).__init__()
#         ...
# ```
#
# - **Class Initialization:** Also `CNN` class inherits from `nn.Module`, laying the foundation for all neural network modules in PyTorch.
#
# ##### Convolutional Layers
#
# ```python
# self.conv_layer = nn.Sequential(
#     ...
#     nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
#     nn.BatchNorm2d(32),
#     nn.ReLU(inplace=True),
#     ...
#     nn.MaxPool2d(kernel_size=2, stride=2),
#     ...
# )
# ```
#
# - **Convolutional Blocks:** The `conv_layer` is composed of sequential convolutional blocks, each containing a `nn.Conv2d` layer followed by batch normalization (`nn.BatchNorm2d`) and a ReLU activation function (`nn.ReLU`). These blocks are designed to extract spatial hierarchies of features from the input images.
#     - The first block takes the input image (32x32 pixels with 3 color channels) and applies two convolutional operations, both increasing the depth to 32 while maintaining the spatial dimensions, thanks to padding. A max-pooling layer then reduces the size to 16x16 pixels.
#     - The second block further processes the data, deepening the features to 64 channels and reducing the spatial dimensions to 8x8 pixels through another max-pooling step.
#
# ##### Fully Connected Layers
#
# ```python
# self.fc_layer = nn.Sequential(
#     nn.Dropout(p=self.dropout_rate),
#     nn.Linear(8*8*64, 512),
#     nn.ReLU(inplace=True),
#     nn.Linear(512, 10)
# )
# ```
#
# - **Classification Block:** After extracting and pooling features through convolutional layers, the network transitions to fully connected (FC) layers for classification. A dropout layer is introduced before the FC layers to prevent overfitting by randomly zeroing out some of the inputs during training. The first FC layer flattens the pooled feature maps and reduces the dimension from 8\*8\*64 to 512, followed by a ReLU activation. The final layer maps these features to the 10 output classes of the CIFAR-10 dataset.
#
# </span>

# %%
model = CNN().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4) # L2 regularization

train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device)
plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies)
# Out:
# Epoch [1/50], Training Loss: 1.8423, Training Accuracy: 32.66%, Validation Loss: 1.7281, Validation Accuracy: 36.94%
# Epoch [2/50], Training Loss: 1.4315, Training Accuracy: 47.74%, Validation Loss: 1.5360, Validation Accuracy: 44.66%
# Epoch [3/50], Training Loss: 1.2282, Training Accuracy: 55.38%, Validation Loss: 1.3774, Validation Accuracy: 49.76%
# Epoch [4/50], Training Loss: 1.0679, Training Accuracy: 60.72%, Validation Loss: 1.3668, Validation Accuracy: 51.85%
# Epoch [5/50], Training Loss: 0.9088, Training Accuracy: 67.44%, Validation Loss: 1.3107, Validation Accuracy: 55.51%
# Epoch [6/50], Training Loss: 0.7152, Training Accuracy: 74.54%, Validation Loss: 1.2910, Validation Accuracy: 57.50%
# Epoch [7/50], Training Loss: 0.5572, Training Accuracy: 80.80%, Validation Loss: 1.3233, Validation Accuracy: 58.17%
# Epoch [8/50], Training Loss: 0.4807, Training Accuracy: 83.06%, Validation Loss: 1.4466, Validation Accuracy: 57.05%
# Epoch [9/50], Training Loss: 0.3659, Training Accuracy: 87.34%, Validation Loss: 1.5174, Validation Accuracy: 56.89%
# Epoch [10/50], Training Loss: 0.2540, Training Accuracy: 91.32%, Validation Loss: 1.5931, Validation Accuracy: 58.26%
# Epoch [11/50], Training Loss: 0.1936, Training Accuracy: 94.06%, Validation Loss: 1.6498, Validation Accuracy: 58.41%
# Epoch [12/50], Training Loss: 0.1327, Training Accuracy: 96.48%, Validation Loss: 1.6923, Validation Accuracy: 58.95%
# Epoch [13/50], Training Loss: 0.1034, Training Accuracy: 97.12%, Validation Loss: 1.8489, Validation Accuracy: 58.86%
# Epoch [14/50], Training Loss: 0.0955, Training Accuracy: 97.18%, Validation Loss: 1.8395, Validation Accuracy: 58.53%
# Epoch [15/50], Training Loss: 0.1280, Training Accuracy: 96.14%, Validation Loss: 1.8760, Validation Accuracy: 58.87%
# Epoch [16/50], Training Loss: 0.1417, Training Accuracy: 95.52%, Validation Loss: 1.9843, Validation Accuracy: 56.92%
# Epoch [17/50], Training Loss: 0.0954, Training Accuracy: 97.08%, Validation Loss: 1.9541, Validation Accuracy: 58.25%
# Epoch [18/50], Training Loss: 0.0481, Training Accuracy: 98.64%, Validation Loss: 1.9872, Validation Accuracy: 59.51%
# Epoch [19/50], Training Loss: 0.0651, Training Accuracy: 98.14%, Validation Loss: 1.9884, Validation Accuracy: 59.37%
# Epoch [20/50], Training Loss: 0.0282, Training Accuracy: 99.40%, Validation Loss: 2.0300, Validation Accuracy: 59.88%
# Epoch [21/50], Training Loss: 0.0162, Training Accuracy: 99.66%, Validation Loss: 2.1916, Validation Accuracy: 60.15%
# Epoch [22/50], Training Loss: 0.0136, Training Accuracy: 99.80%, Validation Loss: 2.1986, Validation Accuracy: 60.53%
# Epoch [23/50], Training Loss: 0.0742, Training Accuracy: 98.00%, Validation Loss: 2.1257, Validation Accuracy: 57.63%
# Epoch [24/50], Training Loss: 0.0291, Training Accuracy: 99.24%, Validation Loss: 2.1868, Validation Accuracy: 58.90%
# Epoch [25/50], Training Loss: 0.0149, Training Accuracy: 99.64%, Validation Loss: 2.2257, Validation Accuracy: 59.91%
# Epoch [26/50], Training Loss: 0.0276, Training Accuracy: 99.14%, Validation Loss: 2.2144, Validation Accuracy: 58.62%
# Epoch [27/50], Training Loss: 0.1157, Training Accuracy: 96.18%, Validation Loss: 2.1827, Validation Accuracy: 58.25%
# Epoch [28/50], Training Loss: 0.0736, Training Accuracy: 97.58%, Validation Loss: 2.1137, Validation Accuracy: 57.41%
# Epoch [29/50], Training Loss: 0.0907, Training Accuracy: 96.84%, Validation Loss: 2.1440, Validation Accuracy: 57.78%
# Epoch [30/50], Training Loss: 0.0303, Training Accuracy: 99.32%, Validation Loss: 2.2758, Validation Accuracy: 57.96%
# Epoch [31/50], Training Loss: 0.2201, Training Accuracy: 92.52%, Validation Loss: 2.1805, Validation Accuracy: 55.45%
# Epoch [32/50], Training Loss: 0.0661, Training Accuracy: 97.90%, Validation Loss: 2.1002, Validation Accuracy: 58.47%
# Epoch [33/50], Training Loss: 0.0302, Training Accuracy: 99.14%, Validation Loss: 2.3267, Validation Accuracy: 58.60%
# Epoch [34/50], Training Loss: 0.0248, Training Accuracy: 99.30%, Validation Loss: 2.3096, Validation Accuracy: 58.50%
# Epoch [35/50], Training Loss: 0.0155, Training Accuracy: 99.60%, Validation Loss: 2.3100, Validation Accuracy: 59.17%
# Epoch [36/50], Training Loss: 0.0081, Training Accuracy: 99.86%, Validation Loss: 2.4463, Validation Accuracy: 59.56%
# Epoch [37/50], Training Loss: 0.0076, Training Accuracy: 99.82%, Validation Loss: 2.4670, Validation Accuracy: 59.82%
# Epoch [38/50], Training Loss: 0.0063, Training Accuracy: 99.86%, Validation Loss: 2.5128, Validation Accuracy: 59.25%
# Epoch [39/50], Training Loss: 0.0177, Training Accuracy: 99.48%, Validation Loss: 2.4255, Validation Accuracy: 58.48%
# Epoch [40/50], Training Loss: 0.0145, Training Accuracy: 99.56%, Validation Loss: 2.5822, Validation Accuracy: 58.04%
# Epoch [41/50], Training Loss: 0.0089, Training Accuracy: 99.82%, Validation Loss: 2.4365, Validation Accuracy: 59.70%
# Epoch [42/50], Training Loss: 0.0072, Training Accuracy: 99.80%, Validation Loss: 2.4692, Validation Accuracy: 60.20%
# Epoch [43/50], Training Loss: 0.0058, Training Accuracy: 99.86%, Validation Loss: 2.4456, Validation Accuracy: 60.25%
# Epoch [44/50], Training Loss: 0.0046, Training Accuracy: 99.86%, Validation Loss: 2.4972, Validation Accuracy: 59.98%
# Epoch [45/50], Training Loss: 0.0063, Training Accuracy: 99.84%, Validation Loss: 2.4995, Validation Accuracy: 60.22%
# Epoch [46/50], Training Loss: 0.0033, Training Accuracy: 99.94%, Validation Loss: 2.5127, Validation Accuracy: 60.07%
# Epoch [47/50], Training Loss: 0.0101, Training Accuracy: 99.72%, Validation Loss: 2.6986, Validation Accuracy: 58.20%
# Epoch [48/50], Training Loss: 0.0207, Training Accuracy: 99.44%, Validation Loss: 2.3729, Validation Accuracy: 58.07%
# Epoch [49/50], Training Loss: 0.0153, Training Accuracy: 99.66%, Validation Loss: 2.2959, Validation Accuracy: 59.34%
# Epoch [50/50], Training Loss: 0.0097, Training Accuracy: 99.80%, Validation Loss: 2.5370, Validation Accuracy: 59.42%
#
# Execution time: 03:40

# %%
# Calculate and print the number of parameters per layer
total_param_num = 0
for name, param in cnn_model.named_parameters():
    print(f"Layer: {name}, Parameters: {param.numel()}")
    total_param_num += param.numel()

print(f"\nTotal number of parameters: {total_param_num}")
# Out:
# Layer: conv_layer.0.weight, Parameters: 864
# Layer: conv_layer.0.bias, Parameters: 32
# Layer: conv_layer.1.weight, Parameters: 32
# Layer: conv_layer.1.bias, Parameters: 32
# Layer: conv_layer.3.weight, Parameters: 9216
# Layer: conv_layer.3.bias, Parameters: 32
# Layer: conv_layer.6.weight, Parameters: 18432
# Layer: conv_layer.6.bias, Parameters: 64
# Layer: conv_layer.7.weight, Parameters: 64
# Layer: conv_layer.7.bias, Parameters: 64
# Layer: conv_layer.9.weight, Parameters: 36864
# Layer: conv_layer.9.bias, Parameters: 64
# Layer: fc_layer.1.weight, Parameters: 2097152
# Layer: fc_layer.1.bias, Parameters: 512
# Layer: fc_layer.3.weight, Parameters: 5120
# Layer: fc_layer.3.bias, Parameters: 10
#
# Total number of parameters: 2168554

# %% [markdown]
# ## Fine-Tuning ResNet
# Fine-tuning a pre-trained model for a specific task like CIFAR-10 image classification represents a powerful strategy in Deep Learning:
#
# - ResNet models pre-trained on ImageNet have learned to recognize a wide variety of features. By starting from these learned parameters, the model can leverage this knowledge, which is particularly beneficial when the dataset is relatively small or when computational resources are limited;
# - While the pre-trained ResNet is knowledgeable about many features, fine-tuning allows it to adapt this knowledge to the specifics of the new task.
# - Fine-tuning a pre-trained model can be more efficient than training a network from scratch, both in terms of computational resources and time required. Additionally, it often leads to better performance, as the model can build upon the complex patterns it has already learned.
# - ResNet architectures incorporate residual connections to mitigate the vanishing gradient problem, allowing effective training of deeper networks. This architectural advantage makes ResNets a strong foundation for building high-performance models.

# %%
class FineTuneResNet(nn.Module):
    def __init__(self, num_classes=10, dropout_rate=0.2):
        super(FineTuneResNet, self).__init__()
        # Load a pre-trained ResNet
        self.resnet = models.resnet18(pretrained=True)
        
        # Remove the final fully connected layer
        num_ftrs = self.resnet.fc.in_features
        self.resnet.fc = nn.Identity()  # Remove the last fully connected layer
        
        # Define the new fully connected layer
        self.fc_layer = nn.Sequential(
            nn.Dropout(p=dropout_rate),
            nn.Linear(num_ftrs, 128),
            nn.ReLU(inplace=True),
            nn.Linear(128, num_classes)
        )
        
    def forward(self, x):
        # Forward through the ResNet layers
        x = self.resnet(x)
        # Forward through the new fully connected layer
        x = self.fc_layer(x)
        return x

finetuned_resnet = FineTuneResNet().to(device)
print(finetuned_resnet)
# Out:
# C:\Users\matte\miniconda3\envs\jads_bootcamp\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\matte\miniconda3\envs\jads_bootcamp\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# FineTuneResNet(
#   (resnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (fc_layer): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=512, out_features=128, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
#
# Let's explore how to fine-tune a pre-trained model, specifically ResNet, originally trained on a large dataset
#
# ```python
# class FineTuneResNet(nn.Module):
#     def __init__(self, num_classes=10, dropout_rate=0.5):
#         super(FineTuneResNet, self).__init__()
#         ...
# ```
#
# - **Initialization:** The `FineTuneResNet` class inherits from `nn.Module`. During initialization, it accepts the number of classes for the new task and a dropout rate, setting the stage for the fine-tuning process.
#
# ```python
# self.resnet = models.resnet18(pretrained=True)
# self.resnet.fc = nn.Identity()  # Remove the last fully connected layer
# ```
#
# - **Load Pre-Trained ResNet:** We begin by loading a pre-trained ResNet-18 model. The `pretrained=True` parameter ensures the model comes with weights learned on the ImageNet dataset, providing a robust feature extractor out of the box.
#
# - **Modifying the Network:** The original fully connected (FC) layer of ResNet, designed for 1000-class ImageNet classification, is replaced with an `nn.Identity()` layer, effectively removing it from the model. This allows us to append custom layers tailored to our specific classification task.
#
# ```python
# num_ftrs = self.resnet.fc.in_features
# self.fc_layer = nn.Sequential(
#     nn.Dropout(p=dropout_rate),
#     nn.Linear(num_ftrs, 128),
#     nn.ReLU(inplace=True),
#     nn.Linear(128, num_classes)
# )
# ```
#
# - **Custom Classification Layer:** We define a new sequence of layers to replace the original ResNet FC layer. This includes a dropout layer for regularization, a linear layer to reduce dimensionality to 128, a ReLU activation, and finally, another linear layer mapping to the number of target classes (`num_classes`).
#
# ```python
# def forward(self, x):
#     x = self.resnet(x)
#     x = self.fc_layer(x)
#     return x
# ```
#
# - **Data Flow:** In the `forward` method, input data `x` first passes through the modified ResNet, extracting high-level features. These features are then processed by our custom FC layer, resulting in the final class predictions.
#
# </span>

# %%
# Calculate and print the number of parameters per layer
total_param_num = 0
for name, param in finetuned_resnet.named_parameters():
    print(f"Layer: {name}, Parameters: {param.numel()}")
    total_param_num += param.numel()

print(f"\nTotal number of parameters: {total_param_num}")
# Out:
# Layer: resnet.conv1.weight, Parameters: 9408
# Layer: resnet.bn1.weight, Parameters: 64
# Layer: resnet.bn1.bias, Parameters: 64
# Layer: resnet.layer1.0.conv1.weight, Parameters: 36864
# Layer: resnet.layer1.0.bn1.weight, Parameters: 64
# Layer: resnet.layer1.0.bn1.bias, Parameters: 64
# Layer: resnet.layer1.0.conv2.weight, Parameters: 36864
# Layer: resnet.layer1.0.bn2.weight, Parameters: 64
# Layer: resnet.layer1.0.bn2.bias, Parameters: 64
# Layer: resnet.layer1.1.conv1.weight, Parameters: 36864
# Layer: resnet.layer1.1.bn1.weight, Parameters: 64
# Layer: resnet.layer1.1.bn1.bias, Parameters: 64
# Layer: resnet.layer1.1.conv2.weight, Parameters: 36864
# Layer: resnet.layer1.1.bn2.weight, Parameters: 64
# Layer: resnet.layer1.1.bn2.bias, Parameters: 64
# Layer: resnet.layer2.0.conv1.weight, Parameters: 73728
# Layer: resnet.layer2.0.bn1.weight, Parameters: 128
# Layer: resnet.layer2.0.bn1.bias, Parameters: 128
# Layer: resnet.layer2.0.conv2.weight, Parameters: 147456
# Layer: resnet.layer2.0.bn2.weight, Parameters: 128
# Layer: resnet.layer2.0.bn2.bias, Parameters: 128
# Layer: resnet.layer2.0.downsample.0.weight, Parameters: 8192
# Layer: resnet.layer2.0.downsample.1.weight, Parameters: 128
# Layer: resnet.layer2.0.downsample.1.bias, Parameters: 128
# Layer: resnet.layer2.1.conv1.weight, Parameters: 147456
# Layer: resnet.layer2.1.bn1.weight, Parameters: 128
# Layer: resnet.layer2.1.bn1.bias, Parameters: 128
# Layer: resnet.layer2.1.conv2.weight, Parameters: 147456
# Layer: resnet.layer2.1.bn2.weight, Parameters: 128
# Layer: resnet.layer2.1.bn2.bias, Parameters: 128
# Layer: resnet.layer3.0.conv1.weight, Parameters: 294912
# Layer: resnet.layer3.0.bn1.weight, Parameters: 256
# Layer: resnet.layer3.0.bn1.bias, Parameters: 256
# Layer: resnet.layer3.0.conv2.weight, Parameters: 589824
# Layer: resnet.layer3.0.bn2.weight, Parameters: 256
# Layer: resnet.layer3.0.bn2.bias, Parameters: 256
# Layer: resnet.layer3.0.downsample.0.weight, Parameters: 32768
# Layer: resnet.layer3.0.downsample.1.weight, Parameters: 256
# Layer: resnet.layer3.0.downsample.1.bias, Parameters: 256
# Layer: resnet.layer3.1.conv1.weight, Parameters: 589824
# Layer: resnet.layer3.1.bn1.weight, Parameters: 256
# Layer: resnet.layer3.1.bn1.bias, Parameters: 256
# Layer: resnet.layer3.1.conv2.weight, Parameters: 589824
# Layer: resnet.layer3.1.bn2.weight, Parameters: 256
# Layer: resnet.layer3.1.bn2.bias, Parameters: 256
# Layer: resnet.layer4.0.conv1.weight, Parameters: 1179648
# Layer: resnet.layer4.0.bn1.weight, Parameters: 512
# Layer: resnet.layer4.0.bn1.bias, Parameters: 512
# Layer: resnet.layer4.0.conv2.weight, Parameters: 2359296
# Layer: resnet.layer4.0.bn2.weight, Parameters: 512
# Layer: resnet.layer4.0.bn2.bias, Parameters: 512
# Layer: resnet.layer4.0.downsample.0.weight, Parameters: 131072
# Layer: resnet.layer4.0.downsample.1.weight, Parameters: 512
# Layer: resnet.layer4.0.downsample.1.bias, Parameters: 512
# Layer: resnet.layer4.1.conv1.weight, Parameters: 2359296
# Layer: resnet.layer4.1.bn1.weight, Parameters: 512
# Layer: resnet.layer4.1.bn1.bias, Parameters: 512
# Layer: resnet.layer4.1.conv2.weight, Parameters: 2359296
# Layer: resnet.layer4.1.bn2.weight, Parameters: 512
# Layer: resnet.layer4.1.bn2.bias, Parameters: 512
# Layer: fc_layer.1.weight, Parameters: 65536
# Layer: fc_layer.1.bias, Parameters: 128
# Layer: fc_layer.3.weight, Parameters: 1280
# Layer: fc_layer.3.bias, Parameters: 10
#
# Total number of parameters: 11243466

# %%
model = FineTuneResNet().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4) # L2 regularization

train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device)
plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies)
# Out:
# Epoch [1/50], Training Loss: 1.4604, Training Accuracy: 48.20%, Validation Loss: 1.1191, Validation Accuracy: 63.20%
# Epoch [2/50], Training Loss: 0.8984, Training Accuracy: 70.28%, Validation Loss: 1.3166, Validation Accuracy: 60.97%
# Epoch [3/50], Training Loss: 0.6719, Training Accuracy: 77.44%, Validation Loss: 1.1928, Validation Accuracy: 63.69%
# Epoch [4/50], Training Loss: 0.5977, Training Accuracy: 80.30%, Validation Loss: 1.4355, Validation Accuracy: 60.57%
# Epoch [5/50], Training Loss: 0.6719, Training Accuracy: 78.72%, Validation Loss: 1.1859, Validation Accuracy: 64.47%
# Epoch [6/50], Training Loss: 0.4069, Training Accuracy: 87.16%, Validation Loss: 1.3141, Validation Accuracy: 63.40%
# Epoch [7/50], Training Loss: 0.4232, Training Accuracy: 86.74%, Validation Loss: 1.2400, Validation Accuracy: 66.65%
# Epoch [8/50], Training Loss: 0.4141, Training Accuracy: 87.26%, Validation Loss: 1.1237, Validation Accuracy: 68.53%
# Epoch [9/50], Training Loss: 0.2267, Training Accuracy: 93.16%, Validation Loss: 1.3751, Validation Accuracy: 66.37%
# Epoch [10/50], Training Loss: 0.3857, Training Accuracy: 88.24%, Validation Loss: 1.3843, Validation Accuracy: 65.43%
# Epoch [11/50], Training Loss: 0.6650, Training Accuracy: 79.42%, Validation Loss: 1.3657, Validation Accuracy: 62.87%
# Epoch [12/50], Training Loss: 0.3337, Training Accuracy: 89.90%, Validation Loss: 1.1673, Validation Accuracy: 67.93%
# Epoch [13/50], Training Loss: 0.3352, Training Accuracy: 89.98%, Validation Loss: 1.2810, Validation Accuracy: 65.75%
# Epoch [14/50], Training Loss: 0.2542, Training Accuracy: 92.22%, Validation Loss: 1.2630, Validation Accuracy: 67.50%
# Epoch [15/50], Training Loss: 0.0911, Training Accuracy: 97.36%, Validation Loss: 1.4433, Validation Accuracy: 68.07%
# Epoch [16/50], Training Loss: 0.1005, Training Accuracy: 96.90%, Validation Loss: 1.3465, Validation Accuracy: 69.13%
# Epoch [17/50], Training Loss: 0.2547, Training Accuracy: 92.68%, Validation Loss: 1.3802, Validation Accuracy: 66.49%
# Epoch [18/50], Training Loss: 0.2065, Training Accuracy: 94.12%, Validation Loss: 1.2839, Validation Accuracy: 68.86%
# Epoch [19/50], Training Loss: 0.2423, Training Accuracy: 92.82%, Validation Loss: 1.2244, Validation Accuracy: 68.26%
# Epoch [20/50], Training Loss: 0.2772, Training Accuracy: 92.04%, Validation Loss: 1.2777, Validation Accuracy: 68.33%
# Epoch [21/50], Training Loss: 0.1269, Training Accuracy: 96.20%, Validation Loss: 1.3922, Validation Accuracy: 68.49%
# Epoch [22/50], Training Loss: 0.1572, Training Accuracy: 95.98%, Validation Loss: 1.3996, Validation Accuracy: 68.44%
# Epoch [23/50], Training Loss: 0.2531, Training Accuracy: 92.64%, Validation Loss: 1.4354, Validation Accuracy: 66.33%
# Epoch [24/50], Training Loss: 0.3736, Training Accuracy: 89.32%, Validation Loss: 1.3352, Validation Accuracy: 67.06%
# Epoch [25/50], Training Loss: 0.1459, Training Accuracy: 95.94%, Validation Loss: 1.3552, Validation Accuracy: 68.72%
# Epoch [26/50], Training Loss: 0.1705, Training Accuracy: 95.20%, Validation Loss: 1.3496, Validation Accuracy: 67.73%
# Epoch [27/50], Training Loss: 0.1177, Training Accuracy: 96.50%, Validation Loss: 1.3702, Validation Accuracy: 68.72%
# Epoch [28/50], Training Loss: 0.0947, Training Accuracy: 97.42%, Validation Loss: 1.4215, Validation Accuracy: 70.32%
# Epoch [29/50], Training Loss: 0.1960, Training Accuracy: 94.38%, Validation Loss: 1.3461, Validation Accuracy: 68.62%
# Epoch [30/50], Training Loss: 0.1057, Training Accuracy: 96.98%, Validation Loss: 1.6620, Validation Accuracy: 64.55%
# Epoch [31/50], Training Loss: 0.5297, Training Accuracy: 85.30%, Validation Loss: 1.2285, Validation Accuracy: 66.26%
# Epoch [32/50], Training Loss: 0.2151, Training Accuracy: 94.30%, Validation Loss: 1.4165, Validation Accuracy: 67.34%
# Epoch [33/50], Training Loss: 0.2190, Training Accuracy: 93.18%, Validation Loss: 1.3363, Validation Accuracy: 67.95%
# Epoch [34/50], Training Loss: 0.1258, Training Accuracy: 96.96%, Validation Loss: 1.4681, Validation Accuracy: 68.28%
# Epoch [35/50], Training Loss: 0.0474, Training Accuracy: 98.74%, Validation Loss: 1.5261, Validation Accuracy: 68.15%
# Epoch [36/50], Training Loss: 0.1926, Training Accuracy: 94.52%, Validation Loss: 1.7016, Validation Accuracy: 63.76%
# Epoch [37/50], Training Loss: 0.2559, Training Accuracy: 93.04%, Validation Loss: 1.3525, Validation Accuracy: 67.39%
# Epoch [38/50], Training Loss: 0.2133, Training Accuracy: 94.36%, Validation Loss: 1.3509, Validation Accuracy: 66.75%
# Epoch [39/50], Training Loss: 0.1265, Training Accuracy: 96.40%, Validation Loss: 1.3891, Validation Accuracy: 67.71%
# Epoch [40/50], Training Loss: 0.0876, Training Accuracy: 97.74%, Validation Loss: 1.4978, Validation Accuracy: 67.56%
# Epoch [41/50], Training Loss: 0.2246, Training Accuracy: 93.56%, Validation Loss: 1.4313, Validation Accuracy: 66.07%
# Epoch [42/50], Training Loss: 0.2914, Training Accuracy: 92.10%, Validation Loss: 1.3823, Validation Accuracy: 66.66%
# Epoch [43/50], Training Loss: 0.0776, Training Accuracy: 97.80%, Validation Loss: 1.4128, Validation Accuracy: 67.86%
# Epoch [44/50], Training Loss: 0.0553, Training Accuracy: 98.64%, Validation Loss: 1.5253, Validation Accuracy: 67.82%
# Epoch [45/50], Training Loss: 0.0947, Training Accuracy: 97.28%, Validation Loss: 1.4607, Validation Accuracy: 67.96%
# Epoch [46/50], Training Loss: 0.1025, Training Accuracy: 97.14%, Validation Loss: 1.5071, Validation Accuracy: 67.64%
# Epoch [47/50], Training Loss: 0.0725, Training Accuracy: 98.08%, Validation Loss: 1.4462, Validation Accuracy: 68.56%
# Epoch [48/50], Training Loss: 0.0572, Training Accuracy: 98.42%, Validation Loss: 1.5566, Validation Accuracy: 68.27%
# Epoch [49/50], Training Loss: 0.1427, Training Accuracy: 95.98%, Validation Loss: 1.5750, Validation Accuracy: 65.69%
# Epoch [50/50], Training Loss: 0.0614, Training Accuracy: 98.32%, Validation Loss: 1.5048, Validation Accuracy: 68.21%
#
# Execution time: 04:50

# %% [markdown]
# ## Data Augmentation

# %%
# Enhanced augmentation + normalization for training
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4), # Randomly crop the images and pad the borders
    transforms.RandomHorizontalFlip(),  # Randomly flip the images on the horizontal axis
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)  # Normalize images
])

# Only normalization for testing, no augmentation
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)  # Normalize images
])

# CIFAR10 datasets with transformations
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
full_train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)

# Reducing the dataset size
indices = list(range(dataset_size))
train_dataset = Subset(full_train_dataset, indices)

# Data loaders
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=worker_init_fn)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, worker_init_fn=worker_init_fn)

print(f"Full train set size: {len(full_train_dataset)} - Reduced train set size: {len(train_dataset)} - Test set size: {len(test_dataset)}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Full train set size: 50000 - Reduced train set size: 5000 - Test set size: 10000

# %% [markdown]
# <span style="font-size:smaller;">
#
# #### Code Breakdown
# Let's enhance the model's generalization capabilities by introducing training data variability.
#
# ```python
# train_transform = transforms.Compose([
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomCrop(28, padding=4),
#     ...
#     transforms.Normalize(mean=mean, std=std)  # Normalize images
# ])
# ```
#
# - **Diverse Augmentations:** The `train_transform` employs a series of augmentation techniques, including random flips, crops, rotations, color jitters, affine translations, and even Gaussian blur. These augmentations artificially expand the dataset by introducing a variety of realistic modifications, helping the model learn from a broader set of data variations and improving its robustness to unseen data.
#
# - **Normalization:** After the augmentation steps, `transforms.ToTensor()` converts the images to PyTorch tensors and apply Standard Normalization, which aids in stabilizing the training process.
#
# ```python
# test_transform = transforms.Compose([
#     transforms.ToTensor(),
#     transforms.Normalize(mean=mean, std=std)
# ])
# ```
#
# - **Consistent Test Data Processing:** For testing, we skip the augmentation steps to evaluate the model on unaltered images, mirroring real-world scenarios. However, normalization remains crucial to align the test data distribution with the transformed training data.
#
# </span>

# %%
model = FineTuneResNet().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4) # L2 regularization

train_losses, train_accuracies, validation_losses, validation_accuracies = train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, device)
plot_metrics(train_losses, train_accuracies, validation_losses, validation_accuracies)
# Out:
# Epoch [1/50], Training Loss: 1.6228, Training Accuracy: 43.12%, Validation Loss: 1.4766, Validation Accuracy: 50.19%
# Epoch [2/50], Training Loss: 1.1758, Training Accuracy: 60.16%, Validation Loss: 1.2264, Validation Accuracy: 59.80%
# Epoch [3/50], Training Loss: 1.1450, Training Accuracy: 60.86%, Validation Loss: 1.3492, Validation Accuracy: 58.12%
# Epoch [4/50], Training Loss: 0.9809, Training Accuracy: 66.76%, Validation Loss: 1.0963, Validation Accuracy: 64.39%
# Epoch [5/50], Training Loss: 0.9831, Training Accuracy: 66.52%, Validation Loss: 1.0199, Validation Accuracy: 66.55%
# Epoch [6/50], Training Loss: 0.8478, Training Accuracy: 71.88%, Validation Loss: 0.9828, Validation Accuracy: 68.49%
# Epoch [7/50], Training Loss: 0.7860, Training Accuracy: 73.88%, Validation Loss: 1.1285, Validation Accuracy: 65.12%
# Epoch [8/50], Training Loss: 0.8513, Training Accuracy: 71.52%, Validation Loss: 0.9150, Validation Accuracy: 69.48%
# Epoch [9/50], Training Loss: 0.7484, Training Accuracy: 74.62%, Validation Loss: 0.9741, Validation Accuracy: 68.83%
# Epoch [10/50], Training Loss: 0.7226, Training Accuracy: 75.76%, Validation Loss: 0.9263, Validation Accuracy: 70.06%
# Epoch [11/50], Training Loss: 0.6416, Training Accuracy: 78.90%, Validation Loss: 0.9803, Validation Accuracy: 70.68%
# Epoch [12/50], Training Loss: 0.7609, Training Accuracy: 74.66%, Validation Loss: 0.9527, Validation Accuracy: 69.43%
# Epoch [13/50], Training Loss: 0.7442, Training Accuracy: 76.24%, Validation Loss: 0.9772, Validation Accuracy: 68.95%
# Epoch [14/50], Training Loss: 0.7031, Training Accuracy: 76.56%, Validation Loss: 0.9550, Validation Accuracy: 70.18%
# Epoch [15/50], Training Loss: 0.6693, Training Accuracy: 77.50%, Validation Loss: 0.9438, Validation Accuracy: 71.13%
# Epoch [16/50], Training Loss: 0.5955, Training Accuracy: 80.42%, Validation Loss: 0.8723, Validation Accuracy: 72.51%
# Epoch [17/50], Training Loss: 0.5528, Training Accuracy: 81.76%, Validation Loss: 0.8707, Validation Accuracy: 72.96%
# Epoch [18/50], Training Loss: 0.6062, Training Accuracy: 79.90%, Validation Loss: 0.8861, Validation Accuracy: 72.05%
# Epoch [19/50], Training Loss: 0.5922, Training Accuracy: 80.22%, Validation Loss: 0.9511, Validation Accuracy: 70.53%
# Epoch [20/50], Training Loss: 0.5851, Training Accuracy: 80.82%, Validation Loss: 0.9023, Validation Accuracy: 71.72%
# Epoch [21/50], Training Loss: 0.4974, Training Accuracy: 83.70%, Validation Loss: 0.9100, Validation Accuracy: 71.96%
# Epoch [22/50], Training Loss: 0.5717, Training Accuracy: 80.68%, Validation Loss: 0.9847, Validation Accuracy: 70.17%
# Epoch [23/50], Training Loss: 0.4820, Training Accuracy: 84.22%, Validation Loss: 0.9840, Validation Accuracy: 70.71%
# Epoch [24/50], Training Loss: 0.4927, Training Accuracy: 83.44%, Validation Loss: 0.9068, Validation Accuracy: 72.44%
# Epoch [25/50], Training Loss: 0.5184, Training Accuracy: 82.54%, Validation Loss: 0.9498, Validation Accuracy: 71.36%
# Epoch [26/50], Training Loss: 0.4047, Training Accuracy: 86.70%, Validation Loss: 0.9104, Validation Accuracy: 72.22%
# Epoch [27/50], Training Loss: 0.4558, Training Accuracy: 85.10%, Validation Loss: 0.9873, Validation Accuracy: 71.71%
# Epoch [28/50], Training Loss: 0.3638, Training Accuracy: 88.24%, Validation Loss: 0.9935, Validation Accuracy: 71.90%
# Epoch [29/50], Training Loss: 0.5973, Training Accuracy: 80.86%, Validation Loss: 0.9102, Validation Accuracy: 72.15%
# Epoch [30/50], Training Loss: 0.4322, Training Accuracy: 85.50%, Validation Loss: 0.9473, Validation Accuracy: 72.87%
# Epoch [31/50], Training Loss: 0.3662, Training Accuracy: 87.78%, Validation Loss: 1.0497, Validation Accuracy: 71.00%
# Epoch [32/50], Training Loss: 0.5135, Training Accuracy: 83.22%, Validation Loss: 0.9513, Validation Accuracy: 72.32%
# Epoch [33/50], Training Loss: 0.3821, Training Accuracy: 87.38%, Validation Loss: 0.9597, Validation Accuracy: 72.65%
# Epoch [34/50], Training Loss: 0.5169, Training Accuracy: 83.14%, Validation Loss: 0.9541, Validation Accuracy: 72.74%
# Epoch [35/50], Training Loss: 0.3856, Training Accuracy: 87.70%, Validation Loss: 0.9929, Validation Accuracy: 72.08%
# Epoch [36/50], Training Loss: 0.5470, Training Accuracy: 82.76%, Validation Loss: 0.9694, Validation Accuracy: 71.02%
# Epoch [37/50], Training Loss: 0.4361, Training Accuracy: 85.86%, Validation Loss: 0.9602, Validation Accuracy: 72.86%
# Epoch [38/50], Training Loss: 0.4310, Training Accuracy: 86.04%, Validation Loss: 0.9446, Validation Accuracy: 72.57%
# Epoch [39/50], Training Loss: 0.3502, Training Accuracy: 88.70%, Validation Loss: 0.9785, Validation Accuracy: 72.37%
# Epoch [40/50], Training Loss: 0.4617, Training Accuracy: 85.22%, Validation Loss: 0.9568, Validation Accuracy: 72.39%
# Epoch [41/50], Training Loss: 0.3375, Training Accuracy: 88.76%, Validation Loss: 0.9895, Validation Accuracy: 73.08%
# Epoch [42/50], Training Loss: 0.3473, Training Accuracy: 88.46%, Validation Loss: 0.9968, Validation Accuracy: 72.13%
# Epoch [43/50], Training Loss: 0.3707, Training Accuracy: 88.18%, Validation Loss: 0.9751, Validation Accuracy: 72.52%
# Epoch [44/50], Training Loss: 0.3564, Training Accuracy: 88.38%, Validation Loss: 0.9807, Validation Accuracy: 73.03%
# Epoch [45/50], Training Loss: 0.3212, Training Accuracy: 89.38%, Validation Loss: 0.9287, Validation Accuracy: 73.77%
# Epoch [46/50], Training Loss: 0.2474, Training Accuracy: 91.84%, Validation Loss: 1.0319, Validation Accuracy: 72.45%
# Epoch [47/50], Training Loss: 0.4068, Training Accuracy: 87.56%, Validation Loss: 0.9778, Validation Accuracy: 72.68%
# Epoch [48/50], Training Loss: 0.4001, Training Accuracy: 86.94%, Validation Loss: 0.9738, Validation Accuracy: 72.39%
# Epoch [49/50], Training Loss: 0.4666, Training Accuracy: 84.94%, Validation Loss: 0.9599, Validation Accuracy: 73.30%
# Epoch [50/50], Training Loss: 0.2850, Training Accuracy: 91.00%, Validation Loss: 0.9540, Validation Accuracy: 74.75%
#
# Execution time: 04:39
